# %% [markdown]
# # Week 6: Networks

# %% [markdown]
# A network is a way to represent a system of things that interact or are interrelated in some fashion. It could just be your facebook network, that's obvious, but a network can also represent the interaction patterns of proteins in the human body, who votes what on whose bill in the US Senate, the mutually attractive forces between galaxies in the universe or just about anything else that you can possibly imagine. This week we are going to study how characters in the Marvel universe relate to each other using networks. In the exercises today you will:
#
# * Get warmed up to thinking about systems as networks
# * Learn to use the `NetworkX` library
# * Explore the partnership network of the Marvel dataset

# %% [markdown]
# [**Questions**](https://github.com/ulfaslak/computational_analysis_of_big_data_2018_fall/issues) **/** [**Feedback**](https://ulfaslak.com/vent)

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Part 0: Networks

# %% [markdown]
# Questions for chapter 1 and 2 of [Network Science](http://barabasi.com/networksciencebook/).

# %% [markdown]
# > **Ex. 6.0.1**: List three different real networks and state the nodes and links for each of them.

# %% [markdown]
# > **Ex. 6.0.2**: What networks are you personally most interested in. Address the following questions:
# >   * What are its nodes and links?
# >   * How large is it?
# >   * Can be mapped out?
# >   * Why do you care about it?

# %% [markdown]
# WikiPedia pages.
# * Nodes are WikiPedia webpages, edges are the links to other Wikipedia pages in that page
# * It is massive
# * Yes
# * It's interesting

# %% [markdown]
# > **Ex. 6.0.3**: In your view what would be the area where network science could have the biggest impact in the next decade? Explain your answer - and base it on the text in the book.

# %% [markdown]
# Advertising.

# %% [markdown]
# > **Ex. 6.0.4**: Section 2.5 states that real networks are sparse. Can you think of a real network where each node has *many* connections? Is that network still sparse? If yes, can you explain why?

# %% [markdown]
# ### Part 1: The `NetworkX` library

# %% [markdown]
# `NetworkX` is the Python library we will be using for working with networks. It should come installed with your Anaconda distribution, but you wont know how to use it yet. The best way to get familiar is to work through a tutorial. That's what the following exercises are about.

# %% [markdown]
# > **Ex. 6.1.1**: Go to the `NetworkX` project's [tutorial page](https://networkx.github.io/documentation/stable/tutorial.html). Read the first few sections about nodes, edges and attributes. Write an example below where you create a graph, `G`, and then:
# 1. add some nodes and edges to,
# 2. print its nodes and edges
# 3. delete a node, and
# 4. plot it.

# %%
import os
import re
import requests as rq
import pandas as pd
import numpy as np
import urllib3 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)  # Suppress InsecureRequestWarning

def get_marvel_character_list(character_type):
    """Returns a set of one type of Marvel Characters (either superheroes or supervillains)
    
    Using the rq.get() method, request the WikiPedia page containing the list of either character type
    defined by the user, then store the .json result into a dictionary, with the continue keyword if it 
    exists. In a loop, keys into query and categorymembers to access title, which contains the character
    name to be added into a set, requests another query with the continue key. If there is a KeyError,
    Then there is no more continue data to be keyed into.
    
    Args:
        characters: string describing the type of marvel characters ("superheroes or supervillains")
        
    Returns: 
        list: a set of the character names
    """
    
    group = set()  
    
    wpage = r"https://en.wikipedia.org/w/api.php?"
    action = r"action=query"
    format = r"format=json"
    list = r"list=categorymembers"
    title = r"cmtitle=Category:Marvel_Comics_%s" % character_type
    url = wpage + "&".join([action,format,list,title])
    
    data = rq.get(url).json()
    cont = data['continue']['cmcontinue']
    
    for entry in data['query']['categorymembers']:
        group.add(entry['title'])
    while True:
        try:
            data = rq.get(url + "&cmcontinue=%s" % cont).json()
            cont = data['continue']['cmcontinue']

            for entry in data['query']['categorymembers']:
                group.add(entry['title'])
        except KeyError:
            break
    return group

def make_groups(**offline):
    """Partitions the three main groups
    
    Defines global variables for each then makes the superheroes and supervillain
    sets. If offline, the markups are already stored on the directory, so to make
    the groups, just make a set of list of files in each directory. Else, forms the 
    superheroes and supervillains from requests (takes long) and  forms the ambiguous 
    set which is the intersection then, subtracts them from each group.
    
    Args:
        offline: a keyword argument specifying if the groups should be made from 
        the existing directory or from requesting. The former is much faster as it
        just accesses the already-stored markups on each of the character folders,
        instead of requesting all over again.
    Returns:
        a tuple of superheroes, supervillains, ambiguous in that order.
    """
    
    def clean_data(data):
        """Cleans the set by removing entries with 'Category' or 'List of'."""
        for item in data.copy():
            if item.find("Category") != -1 or item.find("List of") != -1:
                data.remove(item)
        return data
    
    global superheroes, supervillains, ambiguous
    
    if offline:  # Must have the the stored directory hierarchy already.
        for group, faction in enumerate(['superheroes', 'supervillains', 'ambiguous']):  # Each file has a .txt extension
            faction_chars = [c[:-4] for c in os.listdir('characters/%s' % faction)]      # So splice each until [:-4]
            
            if group == 0:
                superheroes = clean_data(faction_chars)
                
            elif group == 1:
                supervillains = clean_data(faction_chars)
            
            elif group == 2:
                ambiguous = clean_data(faction_chars)
        
    else:          
        superheroes = get_marvel_character_list("superheroes")
        supervillains = get_marvel_character_list("supervillains")
        ambiguous = superheroes.intersection(supervillains)
        superheroes -= ambiguous
        supervillains -= ambiguous
        
    return superheroes, supervillains, ambiguous

superheroes, supervillains, ambiguous = make_groups(offline=True)

# %%
plt.style.use('dark_background')

G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(2,5),(5,4),(3,2),(4,1)])
plt.subplot(1,2,1)
nx.draw(G, with_labels=True)

G.remove_node(2)
plt.subplot(1,2,2)
nx.draw(G)

plt.show()

# %% [markdown]
# > **Ex. 6.1.2**: `NetworkX` has lots of functions to generate synthetic networks. One of the most famous types of synthetic networks is called an Erdős–Rényi (ER) network.
# 1. Describe how to create an ER network.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-2.2/reference/generators.html), find a method you can use for generating an ER network. Create one with $N=100$ nodes and probability of edge creation $p=0.1$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created ER graph.
#     * A node's *degree* is the number of other nodes it is connected to.
#     * The *degree distribution* is a histogram which shows the distribution of node degrees.

# %%
#2.
er = nx.fast_gnp_random_graph(100,0.1)

#3.
ax1 = plt.figure(figsize=(15,15))
nx.draw(er)

#4
def get_degrees(graph):
    degrees = []
    for x, y in graph.adj.items():
        degrees.append(len(y.keys()))
    return degrees

er_degrees = get_degrees(er)

ax2 = plt.figure(figsize=(5,5))
plt.hist(er_degrees)
plt.xlabel("Degrees")
plt.title("Distribution of the ER Graph degrees")


plt.show()

# %% [markdown]
# > **Ex. 6.1.3**: Another very famous type of synthetic network is the Barabási–Albert (BA) network.
# 1. Describe what a BA network is and how to create one.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-2.2/reference/generators.html), find a method you can use for generating a BA network. Create one with $N=100$ nodes and number of new edges from each new node $m=2$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created BA graph.
# 5. Explain the main difference(s) you observe, when comparing to the ER network.
# 6. Are there other measures we could have used to describe the ER and BA networks further?

# %%
#2
ba = nx.barabasi_albert_graph(100,2)

#3
ax3 = plt.figure(figsize=(15,15))
nx.draw(ba)

#4
ba_degrees = get_degrees(ba)
ax4 = plt.figure(figsize=(5,5))
plt.hist(ba_degrees)
plt.xlabel("Degrees")
plt.title("Distribution of the BA Graph degrees")

plt.show()

#5
"""
The distribution of the ER Graph is a bell distribution, while the BA Graph is tail-heavy
"""
# Out:
# '\nThe distribution of the ER Graph is a bell distribution, while the BA Graph is tail-heavy\n'

# %% [markdown]
# ### Part 2: Marvel character partners

# %% [markdown]
# Now that you know how to build a network in `NetworkX`, visualize it and plot some statistics, you are ready to analyze our Marvel dataset. The aim of the following exercises is to analyze the network *partnerships* between characters.

# %% [markdown]
# > **Ex. 6.2.1**: Write a function called `get_partners` that takes a character name, and extracts a list of their partners. Print the partnerships of Iron Man. They should be `['War Machine', 'Pepper Potts', 'Riri Williams']`.
#
# >*Hint: Partnerships for a character are listed in the same way that alliances are. You can probably save yourself some time by looking at your solution to Ex. 4.1.1. Especially if you made use of regular expressions.*

# %%
all_heroes = sorted(superheroes + supervillains + ambiguous)

# %%
len(all_heroes)
# Out:
# 1962

# %%
import re, os

def get_partners(char, faction=None):
    """Return list of alliances for Marvel character."""
    if faction is None:
        for faction in ["superheroes", "supervillains", "ambiguous"]:
            #a list of characters in faction, with each of the file name without the .txt
            faction_chars = [c[:-4] for c in os.listdir("characters/%s" % faction)]
            if char in faction_chars:
                break
    
    # Load character markup
    with open("characters/%s/%s.txt" % (faction, char)) as fp:
        markup = fp.read()
        
    # Get partners field
    partners_field = re.findall(r"\| *partners[\w\W]+?\|.+=", markup)
    if partners_field == []:
        return []
 
    # Extract links from partners field
    return [t[2:-1] for t in re.findall(r"\[\[.+?[\]\|]", partners_field[0])]

# %% [markdown]
# > **Ex: 6.2.2**: Create a `networkx.Graph` that represents each partnership between characters, as an edge. Print the number of nodes, edges and average degree of the resulting network.

# %%
import numpy as np
marvel = nx.Graph()

for hero in all_heroes:
    try:
        partners = get_partners(hero)
    except IOError:
        continue
    for partner in partners:
        marvel.add_edge(hero,partner)
        
print ("Number of nodes: %d\nNumber of edges: %d\nAverage degree of network: %.4f" % (len(marvel.nodes), len(marvel.edges), np.mean(get_degrees(marvel))))
# Out:
# Number of nodes: 9715
# Number of edges: 29981
# Average degree of network: 6.1721

# %%
m_ax = plt.figure(figsize=(20,20))
nx.draw(marvel)

# %% [markdown]
# > **Ex: 6.2.3**: Plot the degree distribution of your character network. What type of random network does it resemble?

# %%
marvel_dist = get_degrees(marvel)

# %%
plt.hist(marvel_dist,bins=200)
# Out:
# (array([7.827e+03, 7.340e+02, 2.930e+02, 1.510e+02, 1.030e+02, 7.700e+01,
#         5.400e+01, 2.700e+01, 4.400e+01, 2.900e+01, 2.700e+01, 1.600e+01,
#         2.700e+01, 1.700e+01, 1.900e+01, 1.000e+01, 1.500e+01, 2.600e+01,
#         1.000e+01, 9.000e+00, 1.300e+01, 9.000e+00, 1.500e+01, 3.000e+00,
#         3.000e+00, 5.000e+00, 7.000e+00, 7.000e+00, 3.000e+00, 8.000e+00,
#         3.000e+00, 5.000e+00, 1.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#         4.000e+00, 5.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 9.000e+00,
#         5.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 7.000e+00, 2.000e+00,
#         1.000e+00, 2.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 0.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         1.000e+00, 0.000e+00, 1.000e+00, 3.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         2.000e+00, 1.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 2.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  1.   ,   3.875,   6.75 ,   9.625,  12.5  ,  15.375,  18.25 ,
#          21.125,  24.   ,  26.875,  29.75 ,  32.625,  35.5  ,  38.375,
#          41.25 ,  44.125,  47.   ,  49.875,  52.75 ,  55.625,  58.5  ,
#          61.375,  64.25 ,  67.125,  70.   ,  72.875,  75.75 ,  78.625,
#          81.5  ,  84.375,  87.25 ,  90.125,  93.   ,  95.875,  98.75 ,
#         101.625, 104.5  , 107.375, 110.25 , 113.125, 116.   , 118.875,
#         121.75 , 124.625, 127.5  , 130.375, 133.25 , 136.125, 139.   ,
#         141.875, 144.75 , 147.625, 150.5  , 153.375, 156.25 , 159.125,
#         162.   , 164.875, 167.75 , 170.625, 173.5  , 176.375, 179.25 ,
#         182.125, 185.   , 187.875, 190.75 , 193.625, 196.5  , 199.375,
#         202.25 , 205.125, 208.   , 210.875, 213.75 , 216.625, 219.5  ,
#         222.375, 225.25 , 228.125, 231.   , 233.875, 236.75 , 239.625,
#         242.5  , 245.375, 248.25 , 251.125, 254.   , 256.875, 259.75 ,
#         262.625, 265.5  , 268.375, 271.25 , 274.125, 277.   , 279.875,
#         282.75 , 285.625, 288.5  , 291.375, 294.25 , 297.125, 300.   ,
#         302.875, 305.75 , 308.625, 311.5  , 314.375, 317.25 , 320.125,
#         323.   , 325.875, 328.75 , 331.625, 334.5  , 337.375, 340.25 ,
#         343.125, 346.   , 348.875, 351.75 , 354.625, 357.5  , 360.375,
#         363.25 , 366.125, 369.   , 371.875, 374.75 , 377.625, 380.5  ,
#         383.375, 386.25 , 389.125, 392.   , 394.875, 397.75 , 400.625,
#         403.5  , 406.375, 409.25 , 412.125, 415.   , 417.875, 420.75 ,
#         423.625, 426.5  , 429.375, 432.25 , 435.125, 438.   , 440.875,
#         443.75 , 446.625, 449.5  , 452.375, 455.25 , 458.125, 461.   ,
#         463.875, 466.75 , 469.625, 472.5  , 475.375, 478.25 , 481.125,
#         484.   , 486.875, 489.75 , 492.625, 495.5  , 498.375, 501.25 ,
#         504.125, 507.   , 509.875, 512.75 , 515.625, 518.5  , 521.375,
#         524.25 , 527.125, 530.   , 532.875, 535.75 , 538.625, 541.5  ,
#         544.375, 547.25 , 550.125, 553.   , 555.875, 558.75 , 561.625,
#         564.5  , 567.375, 570.25 , 573.125, 576.   ]),
#  <a list of 200 Patch objects>)

# %% [markdown]
# > **Ex: 6.2.4**: Create a bar chart (similar in style to the one in Ex. 3.2.1) with the 10 most high-degree characters in each class. Make sure that each subfigure has the same y-axis (control with `plt.ylim` or use `plt.subplots` with parameter `sharey=True`).

# %%
hero_partner = []
villain_partner = []
amb_partner = []

hero_graph = nx.Graph()
villain_graph = nx.Graph()
amb_graph = nx.Graph()
for fc, faction in enumerate(["superheroes", "ambiguous", "supervillains"]):
    faction_chars = [c[:-4] for c in os.listdir("characters/%s" % faction)]
    for char in faction_chars:
        try:
            partners = get_partners(char)
        except IOError:
            continue
        for p in partners:
            if fc == 0:
                hero_graph.add_edge(char, p)
                hero_partner.append((char,p))
            elif fc == 1:
                amb_graph.add_edge(char,p)
                amb_partner.append((char,p))
            elif fc == 2:
                villain_graph.add_edge(char,p)
                villain_partner.append((char,p))

# %%
from collections import OrderedDict
hero_top = OrderedDict(sorted(hero_graph.degree,key=lambda x: x[1],reverse=True)[:10])
villain_top = OrderedDict(sorted(villain_graph.degree,key=lambda x: x[1],reverse=True)[:10])
amb_top = OrderedDict(sorted(amb_graph.degree,key=lambda x: x[1],reverse=True)[:10])

# %%
ax = plt.figure(figsize=(13,18))

ax1 = plt.subplot(3,1,1)
plt.bar(hero_top.keys(), hero_top.values())
plt.xticks(rotation=60)
plt.title("Top 10 Hero by degrees")

plt.subplot(3,1,2,sharey=ax1)
plt.bar(villain_top.keys(), villain_top.values(),color='r')
plt.xticks(rotation=60)
plt.title("Top 10 Villains by degrees")

plt.subplot(3,1,3,sharey=ax1)
plt.bar(amb_top.keys(), amb_top.values(),color='m')
plt.xticks(rotation=60)
plt.title("Top 10 Amb by degrees")

plt.tight_layout()
plt.show()

# %% [markdown]
# > **Ex: 6.2.5**: Create a bar chart (similar in style to the one in Ex. 3.2.1) for each class with the characters that has the highest [betweenness centrality](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.centrality.betweenness_centrality.html) (BC). Again, make sure the y-axes are shared. When you comment on the result:
# * Explain briefly what the BC measures (and why it takes a short while to compute it). An intuitive explanation is also great!
# * Interpret, if you can, what the differences you see between the distribution of degree and BC means for the different classes.

# %%
hero_bc = nx.betweenness_centrality(hero_graph)
villain_bc = nx.betweenness_centrality(villain_graph)
amb_bc = nx.betweenness_centrality(amb_graph)

# %%
amb_bc
# Out:
# {'Abner Jenkins': 0.08844246494372511,
#  'Collector (comics)': 0.0,
#  'Justin Hammer': 0.0009871995726140816,
#  'Gladiator (Melvin Potter)': 0.0,
#  'Powered armor': 0.00010868266708083746,
#  'Beetle (comics)': 0.00010868266708083746,
#  'fictional character': 0.008690764936613941,
#  'American comic book': 0.09803413493633792,
#  'Marvel Comics': 0.17551665077462608,
#  'Strange Tales': 0.00036308422785233076,
#  'Stan Lee': 0.014029879248975242,
#  'Carl Burgos': 0.0,
#  'Incredible Hulk': 0.0,
#  'Thunderbolts (comics)': 0.006617906368527319,
#  'Human Torch': 0.0021161755953400924,
#  'Thing (comics)': 0.0009871995726140816,
#  'Fantastic Four': 0.004080112433898196,
#  'Spider-Man': 0.03146124698036173,
#  'Sinister Syndicate': 0.0,
#  'Onslaught (comics)': 0.0016513290312348842,
#  'Helmut Zemo': 0.00033173609676975796,
#  'Avengers (comics)': 0.024560283006909704,
#  'WP:NFCC': 0.0,
#  'File:Spider-Man Web of Doom 3.jpg': 0.0,
#  'Shawn McManus': 0.0,
#  'Baltimore, Maryland': 0.0,
#  'cybernetics': 0.0,
#  'Daredevil (Marvel Comics character)': 0.001304656335905139,
#  'Defenders (comics)': 0.0023764328416539075,
#  'Iron Man': 0.012823600400972935,
#  'Tinkerer': 0.0008070399497594423,
#  'Ringer (comics)': 0.0,
#  'Egghead (Marvel Comics)': 0.000158307716203319,
#  'Masters of Evil': 0.0035022430678915547,
#  'Blizzard (Donnie Gill)': 0.0,
#  'Blacklash': 0.0003949128977952668,
#  'Force (comics)': 0.0,
#  'Earth': 0.0,
#  'Baron Zemo#Baron Helmut Zemo': 0.0,
#  'Hawkeye (comics)': 0.0048917006424877615,
#  'Commission on Superhuman Activities': 0.0,
#  'blackmail': 0.0,
#  'African American': 0.0,
#  'Henry Peter Gyrich': 0.0,
#  'vigilante': 0.0,
#  'Burton Canyon': 0.0,
#  'Colorado': 0.0,
#  'police department': 0.0,
#  'tech support': 0.0,
#  'Graviton (comics)': 0.00010140318338389682,
#  'Citizen V': 0.0,
#  'V-Battalion': 0.0,
#  'Counter-Earth (comics)': 0.0,
#  'Attilan': 0.0,
#  'white hole': 0.0,
#  'radiation': 0.0,
#  'Illinois': 0.0,
#  'Moonstone (comics)': 0.0,
#  'Jolt (comics)': 0.00010140318338389682,
#  'parole': 0.0,
#  'Baron Wolfgang Von Strucker': 0.0,
#  'Speed Demon (comics)': 0.0,
#  'Fathom Five (comics)': 0.0,
#  'New York City': 0.00441797223493533,
#  'Hydra (Marvel Comics)': 0.00496325978454969,
#  'Manhattan': 0.0,
#  'Black Widow (Natalia Romanova)': 0.002794534287103832,
#  'Norman Osborn': 0.0014568167527845499,
#  'H.A.M.M.E.R.': 0.00044923893344647064,
#  'Luke Cage': 0.0035718155685638083,
#  'Man-Thing': 0.0,
#  'Avengers: Standoff!': 0.0006599775318857411,
#  'powered armor': 0.0,
#  'Head-up display': 0.0,
#  'Marvel Zombies': 0.0037519098259605355,
#  'Thor (Marvel Comics)': 0.003821621714826792,
#  'Nova (Richard Rider)': 0.0,
#  'Erik Josten': 0.07152673429551719,
#  'Howling Commandos': 0.00010036537731058316,
#  'Dum Dum Dugan': 0.00010036537731058316,
#  'Kree': 0.0003949128977952668,
#  "Shi\\'ar": 0.0,
#  'House of M': 0.017111042482784174,
#  'Ultimate Marvel': 0.021316050432463225,
#  'Daily Bugle': 0.0013901933093168578,
#  'Secret Wars (2015 comic book)': 0.0006707804465200471,
#  'Amazing Spider-Man: Renew Your Vows': 0.00030725117121287903,
#  'List of Marvel Comics characters: R#Regent': 0.00030725117121287903,
#  'Old Man Logan': 0.0012590707323373404,
#  'Spider-Man and His Amazing Friends': 0.0004565058658442979,
#  'Iron Man (TV series)': 0.00041723873515539387,
#  'John Reilly (actor)': 0.0,
#  'Liverpool': 0.0,
#  'Beatles': 0.0,
#  'cameo appearance': 0.0015261153236644806,
#  'Ultimate Spider-Man (TV series)': 0.003568715368914763,
#  'New Warriors': 0.007155225110420861,
#  'White Tiger (Ava Ayala)': 0.0,
#  'Avengers Assemble (TV series)': 0.0010235579714645239,
#  'Mark C. Hanson': 0.0,
#  'Spider-Man (2017 TV series)': 0.007149115019585855,
#  'Fred Tatasciore': 0.002124346931599491,
#  'Eddie Brock': 0.0016841059223409098,
#  'J. Jonah Jameson': 0.0005492342119690883,
#  'Super Nintendo Entertainment System': 0.0004565058658442979,
#  'Sega Genesis': 0.0004565058658442979,
#  'Spider-Man Animated Series (video game)': 0.0,
#  'Spider-Man (1994 TV series)': 0.00030725117121287903,
#  'Spider-Man: Lethal Foes': 0.0,
#  'PlayStation': 0.0,
#  'Spider-Man 2: Enter Electro': 0.0,
#  'Spider-Man: The Animated Series': 0.0005413377940210291,
#  'Blue Streak (comics)': 0.012014975209929817,
#  'Ricadonna': 0.0,
#  'Civil War (comics)': 0.00039197759951709363,
#  'Secret Empire (comics)': 0.0012347910376506277,
#  'Image:BluestreakAN.JPG': 0.0,
#  'Mutant (Marvel Comics)': 0.005866624304630233,
#  'A-Next': 0.0,
#  'Tom DeFalco': 8.664089983432134e-05,
#  'Brent Anderson': 0.0,
#  'Dream Team (comics)': 0.0,
#  'X-People': 0.0,
#  'Quicksilver (comics)': 0.0009550769039967212,
#  'Marvel Comics 2': 0.0019071498148024182,
#  'Earth-616': 0.0020818365438118177,
#  'X-Men': 0.005379460295885033,
#  'Avengers (comics)#Avengers Next': 0.0,
#  'J2 (comics)': 0.00031000224934913886,
#  'Mainframe (comics)': 0.0,
#  'Copycat (Marvel Comics)': 0.03860887952323102,
#  'Deadpool': 0.0060739463147464565,
#  'Mary MacPherran': 0.0,
#  'Garrison Kane': 0.0,
#  'Domino (comics)': 0.00020792122284858772,
#  'X-Force': 0.0008834821145171699,
#  'Morena Baccarin': 0.0,
#  'Deadpool (film)': 0.0,
#  'Deadpool 2': 0.00035583684774177207,
#  '1993 in comics': 0.0,
#  'retconned': 0.0,
#  'The New Mutants (comic book)': 0.0,
#  '1991 in comics': 0.0,
#  'Fabian Nicieza': 0.0022837808210471565,
#  'Greg Capullo': 0.0,
#  'Boston': 0.0003805193816265592,
#  'Landau, Luckman & Lake': 0.0,
#  'Genesis (Marvel Comics)': 0.0,
#  'Cable (comics)': 0.004323392572949088,
#  'San Francisco': 0.0,
#  'Psycho-Man': 0.0,
#  'Microverse': 0.0,
#  'Siryn': 0.0015502037502957617,
#  'Weapon X': 0.0,
#  'Sabretooth (comics)': 0.0015132757095053032,
#  'shapeshifting': 0.0,
#  'image:CopycatAOA.jpg': 0.0,
#  'Andy Kubert': 0.0,
#  'Age of Apocalypse': 0.0036006910695969684,
#  'Multiple Man': 0.0,
#  'Madison Jeffries': 0.0,
#  'Spyne': 0.0,
#  'Age of X': 0.00038889548306900016,
#  'X-Men (TV series)': 0.00405138342995837,
#  'Asteroid M': 0.0,
#  'Wolverine and the X-Men (TV series)': 0.0019239780648287784,
#  'Rhett Reese': 0.0,
#  'Paul Wernick': 0.0,
#  'strip club': 0.0,
#  'Ajax (comics)': 0.0,
#  'Angel Dust (comics)': 0.0,
#  'Helicarrier': 0.0036670533604232416,
#  'Rusty Collins': 0.00035583684774177207,
#  'Negasonic Teenage Warhead': 0.00035583684774177207,
#  'Yukio (comics)': 0.0011373201654399738,
#  'Crimson Dynamo': 0.1297074228064689,
#  'Armenia': 0.0,
#  'Ph.D': 0.0,
#  'Unicorn (comics)': 0.00021385008365056778,
#  'Stark Industries': 0.0009174850185114951,
#  'United States': 0.0017132126823197595,
#  'Temugin': 0.0,
#  'File:Crimson Dynamo 002.jpg': 0.0,
#  'Iron Man (comic book)': 0.00029106596927466093,
#  'Archie Goodwin (comics)': 0.0,
#  'George Tuska': 0.0,
#  'Human': 0.0,
#  'Titanic Three': 0.0,
#  'CEO': 0.000527963293237325,
#  'Titanium Man': 0.00021385008365056778,
#  'Radioactive Man (comics)': 0.0,
#  'KGB': 0.0,
#  'Official Handbook of the Marvel Universe': 0.0013095069510473234,
#  'Silver Age of Comics': 0.0,
#  'Darkstar (comics)': 0.0,
#  'Griffin (Marvel Comics)': 0.0,
#  'Rampage (Marvel Comics)': 0.0,
#  'Champions (1975 team)': 0.0,
#  'Siberia': 0.0,
#  'File:Yuricrimson.jpg': 0.0,
#  'Dmitri Bukharin': 0.0,
#  'Soviet Super-Soldiers': 0.0,
#  'Supreme Soviets': 0.0,
#  'Dark Reign (comics)': 0.0013095069510473234,
#  'Winter Guard': 0.0,
#  'Demon in a Bottle': 0.0,
#  'Doomquest': 0.0,
#  'Armor Wars': 0.0,
#  'File:Crimson Dynamo Shatalov.jpg': 0.0,
#  'Glenn Herdling': 0.0,
#  'Herb Trimpe': 0.0,
#  'Lethal Legion': 0.0005919461457832238,
#  'Soviet Union': 0.0,
#  'Stalinism': 0.0,
#  'Devastator (comics)': 0.0,
#  'Russia': 0.0,
#  'Nick Fury': 0.0064220901858575916,
#  'Captain America': 0.010855949171121534,
#  'File:Crimsondynamogennady1.jpg': 0.0,
#  'John Jackson Miller': 0.0,
#  'Steve Ellis (comics)': 0.0,
#  'Secret War (comics)': 0.0,
#  'Lucia von Bardas': 0.001050120881827547,
#  'Punisher': 0.004202553883337771,
#  'The Order (comics)': 0.0,
#  'Hulk (comics)': 0.010253467707078055,
#  'S.H.I.E.L.D.': 0.030531053370655002,
#  'Doc Samson': 0.0,
#  'She-Hulk': 0.0016056452228953302,
#  'Abomination (comics)': 0.0001966246078494705,
#  'War Machine': 0.0006063192363091281,
#  'Skrull': 0.0017068421836639162,
#  'Thunderbolt Ross': 0.0,
#  'Hulk: Winter Guard': 0.0,
#  'Mandarin (comics)': 0.0005919461457832238,
#  'Zeke Stane': 0.0009591799092779974,
#  'Gremlin (comics)': 0.0,
#  'Heroes Reborn (comics)': 0.0009023528298479827,
#  'Franklin Richards (Fantastic Four)': 0.0007539247272742394,
#  'Loki (comics)': 0.00042861800121620283,
#  'Black Knight (Nathan Garrett)': 0.0,
#  'The Ultimates': 0.0,
#  'China': 0.0,
#  'Ultimate Iron Man (comics)': 0.0,
#  'Ultimate Fantastic Four': 0.001050120881827547,
#  'Red Ghost': 0.0,
#  'The Marvel Super Heroes': 0.0005919461457832238,
#  'Henry Ramer': 0.0,
#  'William Hootkins': 0.0,
#  'Stuart M. Rosen': 0.0,
#  'Howard Stark': 0.0,
#  'Iron Man: Armored Adventures': 0.00021385008365056778,
#  'Project Pegasus': 0.0,
#  'IV drip': 0.0,
#  'Pepper Potts': 0.000577457541236377,
#  'Iron Monger': 0.00021385008365056778,
#  'Guardsman (comics)': 0.0,
#  'Brian Drummond': 0.0,
#  'Hulkbuster Armor MK II': 0.0,
#  'The Super Hero Squad Show': 0.00235742405523395,
#  'Jess Harnell': 0.0,
#  'Doctor Doom': 0.004316420930725474,
#  'Melter': 0.0,
#  "The Avengers: Earth\\'s Mightiest Heroes": 0.0,
#  'Avengers Mansion': 0.00203976750724798,
#  'Hydra (comics)': 0.003999565943787334,
#  'Enchantress (comics)': 0.0,
#  'Wonder Man': 0.00029106596927466093,
#  'Marvel Cinematic Universe': 0.0028722335174911954,
#  'Agent Carter (TV series)': 0.0,
#  'Costa Ronin': 0.0,
#  'Power Princess': 0.0,
#  'Black Widow (Natasha Romanova)': 0.00029106596927466093,
#  'Falcon (comics)': 0.00042861800121620283,
#  'Laura Bailey (voice actress)': 0.0,
#  'Mickey Rourke': 0.0,
#  'Whiplash (comics)': 0.00021385008365056778,
#  'Iron Man 2': 0.0,
#  'Variety (magazine)': 0.0,
#  'Anton Vanko': 0.0,
#  'Evgeniy Lazarev': 0.0,
#  "Iron Man\\'s armor in other media": 0.0,
#  'black market': 0.0,
#  'The Invincible Iron Man (video game)': 0.0,
#  'Game Boy Advance': 0.0023059489293180296,
#  'Marvel: Ultimate Alliance': 0.0005640244113928165,
#  'Robin Atkin Downes': 0.0,
#  'Marvel Super Hero Squad (video game)': 0.0,
#  'Iron Man 2 (video game)': 0.0,
#  'Dimitri Diatchenko': 0.0,
#  'Facebook': 0.001464452414250352,
#  'Marvel: Avengers Alliance': 0.006181892739820741,
#  'Iron Man 3: The Official Game': 0.0,
#  "Lego Marvel\\'s Avengers": 0.00021385008365056778,
#  'Marvel: Avengers Alliance#Marvel: Avengers Alliance 2': 0.00021385008365056778,
#  'Marvel Avengers Academy': 0.0,
#  'Magneto and Titanium Man': 0.0,
#  'Paul McCartney and Wings': 0.0,
#  'The Classic Marvel Figurine Collection': 0.0,
#  'Hasbro': 0.002739762762522283,
#  'Marvel Super Hero Squad': 0.0,
#  'Minimates': 0.0,
#  'Iron Man 2 (toy line)': 0.0,
#  'Iron Man: The Armored Avenger': 0.0,
#  'Elektro (comics)': 0.01618902362431157,
#  'Fin Fang Foom': 0.0,
#  'robot': 0.0002788979773424438,
#  'Tales of Suspense': 0.00010193326438864897,
#  'penciler': 0.0,
#  'Jack Kirby': 0.0011526976948044864,
#  'Atlas Comics (1950s)#Pre-superhero Marvel': 0.0,
#  'Atlas Comics (1950s)': 0.0,
#  'Mister Fantastic': 0.0003133730409748977,
#  'Baxter Building': 0.0004915094838050682,
#  'extraterrestrials': 0.0,
#  'Googam': 0.0,
#  'Gorgilla': 0.0,
#  'Tim Boo Baa': 0.0,
#  'receptionist': 0.0,
#  'Roberta (comics)': 0.0,
#  'Fin Fang Four': 0.0,
#  'Electro (Marvel Comics)': 0.0007429197315310854,
#  'Swordsman (comics)#Jacques Duquesne': 0.0,
#  'Goliath (Marvel Comics)': 0.0,
#  'Don Heck': 0.0,
#  'The Avengers (comic book)': 0.0,
#  'Peter Parker, The Spectacular Spider-Man': 0.0,
#  'The Incredible Hulk (comic book)': 0.00023773229185105666,
#  'File:powermanatlas.jpg': 0.0,
#  'Wally Wood': 0.0,
#  'Milwaukee, Wisconsin': 0.0,
#  'Heinrich Zemo': 0.0,
#  'Enchantress (Marvel Comics)': 0.0,
#  'Red Skull': 0.011467817364392842,
#  'Count Nefaria': 0.000844167564262331,
#  'File:smuggleratlas.jpg': 0.0,
#  'Smuggler (comics)': 0.0,
#  'Maggia (comics)': 0.001157072019525049,
#  'Karl Malus': 0.0,
#  'Hank Pym': 0.0003107543872534834,
#  'superheroes': 0.0,
#  'West Coast Avengers': 0.001377042268100117,
#  'Grim Reaper (comics)': 0.0,
#  'Man-Ape': 0.0,
#  'Nekra': 0.0,
#  'Ultron': 0.0003701960640694026,
#  'File:goliathatlas.jpg': 0.0,
#  'Hercules (Marvel Comics)': 0.000968929633903759,
#  'Acts of Vengeance': 0.0005112222802903532,
#  'Vault (comics)': 0.0007380441643981474,
#  'Freedom Force (comics)': 0.0003598753085211859,
#  'Bill Foster (comics)': 0.0,
#  'Ant-Man (Scott Lang)': 0.0002230534296889207,
#  'Atlas (Marvel Comics)': 0.0,
#  'Dallas Riordan': 0.0,
#  'Counter Earth': 0.0,
#  'JLA/Avengers': 0.0,
#  'Krona (comics)': 0.0,
#  'Plastic Man': 0.0,
#  'Fixer (comics)#Fixer/Techno': 0.0,
#  'Grandmaster (Marvel Comics)': 0.0009157724469136011,
#  'Camp Hammond (comics)': 0.00026313409026752196,
#  'Fifty State Initiative': 0.0,
#  'Nighthawk (Marvel Comics)': 0.0,
#  'Revengers': 0.0,
#  'List of Marvel Comics characters: K#Kobik': 0.00010140318338389682,
#  'Mail carrier': 0.0,
#  'Monsters Unleashed (comics)': 0.0,
#  'Washington, D.C.': 0.0,
#  'Namor': 0.0,
#  'Hyperion (comics)': 0.0,
#  'AWOL': 0.0,
#  'Mjolnir (comics)': 0.0,
#  'Marvel Adventures: The Avengers': 0.0,
#  'Wasp (comics)': 0.0,
#  'Vulture (Marvel Comics)': 0.0011082402284675428,
#  'Stilt-Man': 0.0007693743338559354,
#  'Blob (comics)': 0.0005112222802903532,
#  'Thunderbird (comics)': 0.0,
#  'Paul Kligman': 0.0,
#  'Jesse Burch': 0.0,
#  'Iron Man and X-O Manowar in Heavy Metal': 0.0,
#  'Fixer (comics)': 0.07249298567526498,
#  'Mentallo': 0.0,
#  'Advanced Idea Mechanics': 0.0,
#  'New Enforcers': 0.0,
#  'Redeemers (comics)': 0.0,
#  'Dayton, Ohio': 0.0,
#  'scientist': 0.0,
#  'supervillain': 0.0061327724706014275,
#  'genius': 0.0,
#  'inventor': 0.0,
#  'Deathlok#Luther Manning': 0.0,
#  'Micronauts (comic book)': 0.0,
#  'Professor Power': 0.0,
#  'Professor X': 0.006453589685683464,
#  "Iron Man\\'s armor": 0.0,
#  'Ka-Zar (comics)': 0.0,
#  'Blackout (Marcus Daniels)': 0.0,
#  'Black Knight (Dane Whitman)': 0.0,
#  'Edwin Jarvis': 0.0,
#  'Super-Adaptoid': 4.148598595478018e-05,
#  'Hydro-Base': 0.0,
#  'Yellowjacket (Rita DeMara)': 0.00021042618643143585,
#  'Kevin Costner': 0.0,
#  'Ogre (Marvel Comics)': 0.0,
#  'Scourge of the Underworld': 0.0003910305815806145,
#  'amnesia': 0.0007172040072714032,
#  'quadriplegic': 0.0,
#  'Civil War (comic book)': 0.00010428706972849128,
#  'Heroic Age (comics)': 0.0,
#  'Ghost (Marvel Comics)': 0.0,
#  'Fear Itself (comics)': 0.0,
#  'Juggernaut (comics)': 0.22642507663552358,
#  'gated community': 0.0,
#  'Cosmic Cube': 0.0024979830179471187,
#  'mechanic': 0.0,
#  'Maria Hill': 0.0,
#  'Erik Selvig': 0.0,
#  'Killer Shrike': 0.00010428706972849128,
#  'anime': 0.0,
#  'Marvel Disk Wars: The Avengers': 0.0005575462527638552,
#  'Daredevil (TV series)': 0.0,
#  'Kevin Nagle': 0.0,
#  'Netflix': 0.0,
#  'Elektra (comics)': 0.0008918712976962121,
#  'Rick D. Wasserman': 0.0,
#  'Daredevil (film)': 0.0,
#  'Mark Margolis': 0.0,
#  'Kingpin (character)': 0.0006671115559641473,
#  'Mentallo and the Fixer': 0.0,
#  'Futurist (comics)': 0.009515062039570846,
#  'Alpha the Ultimate Mutant': 0.0,
#  'Marv Wolfman': 0.0,
#  'John Byrne (comics)': 0.00032445333711867856,
#  'Blastaar': 0.0,
#  'Invisible Woman': 0.0,
#  'Negative Zone': 5.197360529324426e-05,
#  'Quasar (comics)': 0.0,
#  'Stranger (comics)': 0.0,
#  'Harry Osborn': 0.14454536658637437,
#  'Oscorp': 0.0,
#  'Parker Industries': 0.0,
#  'The Amazing Spider-Man': 0.004825369125604702,
#  '1965 in comics': 0.0,
#  'Steve Ditko': 0.0,
#  'Normie Osborn': 0.0,
#  'Green Goblin': 0.0018131742058886766,
#  'Spider-Man in film#Sam Raimi films': 0.0,
#  'James Franco': 0.0,
#  'The Amazing Spider-Man 2': 0.0,
#  'Dane DeHaan': 0.0,
#  'Dorling Kindersley': 0.0,
#  'Gerry Conway': 0.0,
#  'psychedelic drug': 0.0,
#  'hallucinogen': 0.0,
#  'Back Issue!': 0.0010189506576831616,
#  'TwoMorrows Publishing': 0.0010189506576831616,
#  'The Spectacular Spider-Man': 0.00023607017092193045,
#  'Sal Buscema': 0.001799671399792554,
#  'J. M. DeMatteis': 0.0008816869301470876,
#  'Clone Saga': 0.0,
#  'Emily Osborn': 0.0,
#  'Empire State University': 0.0,
#  'clique': 0.0,
#  'Gwen Stacy': 0.0,
#  'Aunt May': 0.0,
#  'superhero': 0.006722206324063658,
#  'cocaine': 0.0,
#  'File:Amazingspider136.jpg': 0.0,
#  'John Romita, Sr.': 0.0,
#  'Mary Jane Watson': 0.00023607017092193045,
#  'amphetamine': 0.0,
#  'bankruptcy': 0.0,
#  'kidnaps': 0.0,
#  'George Washington Bridge': 0.0,
#  'Brooklyn Bridge': 0.0,
#  'goblin glider': 0.0,
#  'hypnosis': 0.0,
#  'Profit (accounting)': 0.0,
#  'Liz Allan': 0.0,
#  'Betty Brant': 0.0,
#  'Ned Leeds': 0.0,
#  'Roderick Kingsley': 0.0,
#  'Jason Macendale': 0.0,
#  'File:Harryosborndeath.jpg': 0.0,
#  'Inferno (Marvel Comics)': 0.0,
#  'subconscious': 0.0,
#  'Mark Raxton': 0.0,
#  'Molten Man': 0.00019784343124031796,
#  'Chameleon (comics)': 0.002977145561438156,
#  'Life Model Decoy': 0.00039903115279016577,
#  'Ben Reilly': 0.0017293172149164457,
#  'Mysterio': 0.0010080793940218337,
#  'Mephisto (comics)': 0.002811347528944493,
#  'Menace (Marvel Comics)': 0.0,
#  'Liberty Island': 0.0,
#  'Statue of Liberty': 0.0,
#  'Dark Avengers': 0.0004662400253170471,
#  'Joe Kelly (writer)': 0.0,
#  'Phil Jimenez': 0.0,
#  'Andy Lanning': 0.0,
#  'Iron Patriot': 0.0,
#  'Marco Checchetto': 0.0,
#  'oxycodone': 0.0,
#  'Mister Negative': 0.00047171057949670363,
#  'Siege (Marvel Comics)': 0.0,
#  'Gabriel Stacy and Sarah Stacy': 0.0,
#  'Norah Winters': 0.0,
#  'Carlie Cooper': 0.00047171057949670363,
#  'Doctor Octopus': 0.008640492809254285,
#  'Vin Gonzales': 0.0,
#  'All-New, All-Different Marvel': 0.003113169656844474,
#  'Carnage (comics)': 0.0,
#  'Spider-Girl': 0.0,
#  'Alternative versions of the Green Goblin#Ultimate Marvel': 0.0,
#  'Jackal (Marvel Comics)': 0.0,
#  'Ultimate Six': 0.0,
#  'Ultimate Spider-Man': 0.0004662400253170471,
#  'Sinister Six': 0.0006266619632482013,
#  'Ultimates': 0.0018131742058886766,
#  'White House': 0.0,
#  'Ultimate Nick Fury': 0.0,
#  'Hobgoblin (comics)': 0.00023607017092193045,
#  'Marvel Zombies: Return': 0.0,
#  'Kaine Parker': 0.0011707200502931586,
#  'Spider-Geddon': 0.0,
#  'Alternative versions of Spider-Man#Spider-Man (Norman Osborn)': 0.0,
#  'Spider-Man (1981 TV series)': 0.0,
#  'Gary Imhoff': 0.0,
#  'Spider-Man: The New Animated Series': 0.0,
#  'Ian Ziering': 0.0,
#  'The Spectacular Spider-Man (TV series)': 0.0,
#  'James Arnold Taylor': 0.0,
#  'Flash Thompson': 0.002206884695385478,
#  'Gwen Stacey': 0.0,
#  'Matt Lanter': 0.0,
#  'Venom (Marvel Comics character)': 0.004651146326290365,
#  'Klaw (comics)': 0.0,
#  'Frightful Four': 0.0,
#  'Taskmaster (comics)': 0.0004662400253170471,
#  'Nick Fury (Ultimate Marvel character)': 0.0,
#  'Lizard (comics)': 0.0,
#  'Iron Patriot#American Son': 0.0,
#  'Anti-Venom (symbiote)': 0.0,
#  'Spider-Man (Miles Morales)': 0.00023607017092193045,
#  'Morbius, the Living Vampire': 0.00047171057949670363,
#  'Triskelion (comics)': 0.0,
#  'Max Mittelman': 0.0,
#  'File:New Goblin front view.jpg': 0.0,
#  'Spider-Man 3': 0.0,
#  'Sam Raimi': 0.0,
#  'Spider-Man (2002 film)': 0.0,
#  'Spider-Man 2': 0.0,
#  'fusion reactor': 0.0,
#  'Symbiote (comics)': 0.0,
#  'Bernard Houseman': 0.0,
#  'Sandman (Marvel Comics)': 0.00023607017092193045,
#  'Donald Menken': 0.0,
#  'Marvel Studios': 0.0,
#  'Spider-Man (2002 video game)': 0.0,
#  'Josh Keaton': 0.0,
#  'Spider-Man 2 (video game)': 0.00023607017092193045,
#  'Spider-Man 3 (video game)': 0.0,
#  'Xbox 360': 0.0,
#  'PlayStation 3': 0.0,
#  'Spider-Man: Friend or Foe': 0.0,
#  'The Amazing Spider-Man 2 (2014 video game)': 0.0,
#  'Kevin Dorman': 0.0,
#  'Richard and Mary Parker': 0.0,
#  'Spider-Man (2018 video game)': 0.00047171057949670363,
#  'Scott Porter': 0.0,
#  'Hellfire (J. T. Slade)': 0.02273240509510153,
#  'The Mighty Avengers': 0.0,
#  'Brian Michael Bendis': 0.0005849417804554319,
#  'Alex Maleev': 0.0,
#  'Carter Slade': 0.0,
#  'Secret Invasion': 0.0009705968513960137,
#  'Secret Warriors (comic book)': 0.0,
#  'Inhumans': 3.256920639437866e-05,
#  'Agents of S.H.I.E.L.D.': 0.0,
#  'Axle Whitehead': 0.0,
#  'The Futon Critic': 0.0,
#  'IGN': 0.0009092607236572884,
#  'Paradise Lost (Agents of S.H.I.E.L.D.)': 0.0,
#  'American Broadcasting Company': 0.0,
#  'The Singularity (Agents of S.H.I.E.L.D.)': 0.0,
#  'Terrigen Mist': 0.0,
#  'Hive (comics)': 0.0,
#  'Holden Radcliffe': 0.0,
#  'Ascension (Agents of S.H.I.E.L.D.)': 0.0,
#  'Let Me Stand Next to Your Fire': 0.0,
#  'Ghost Rider (Robbie Reyes)': 0.0,
#  'Janice Lincoln': 0.024230796602336534,
#  'Tombstone (comics)': 0.0001196493263064236,
#  'fictional': 0.0006834292020760311,
#  'supervillainess': 0.0,
#  'Captain America (comic book)': 0.00012617835422755713,
#  'Ed Brubaker': 0.0,
#  'Superior Foes of Spider-Man': 0.0,
#  'Mitch Breitweiser': 0.0,
#  'Butch Guice': 0.0,
#  'Raft (comics)': 0.0,
#  'Rick Magyar': 0.0,
#  'Mark Pennington': 0.0,
#  'Marvel NOW!': 0.0,
#  'The Superior Spider-Man': 0.001792170762405605,
#  'Silvermane': 0.0,
#  'Owl (Marvel Comics)': 0.0,
#  'The Superior Foes of Spider-Man': 0.0,
#  'Prodigy (David Alleyne)': 0.000125987496405791,
#  'Victor Mancha': 0.0,
#  'Miami': 0.0,
#  'Black Tom Cassidy': 0.0,
#  'Silver Age of Comic Books': 0.0,
#  'One-shot (comics)': 0.0,
#  'clothing': 0.0,
#  'toy': 0.0,
#  'trading card': 0.0,
#  'animated': 0.0,
#  'television series': 0.0,
#  'video game': 0.0,
#  'X-Men: The Last Stand': 0.00044253647251767835,
#  'Vinnie Jones': 0.0,
#  'Ryan Reynolds': 0.0,
#  'Wizard (magazine)': 0.0,
#  'Flashback (narrative)': 0.0006135430196822384,
#  'Doctor Strange': 0.0031965852489497016,
#  'Beast (comics)': 0.0019931689568235553,
#  'Spider-Woman': 0.0008244011341923769,
#  'Secret Wars II': 0.0007685433786945208,
#  'Marvel Saga': 0.0,
#  'Excalibur (comics)': 0.0,
#  'Cyttorak': 0.0,
#  'X-Men Unlimited': 0.0,
#  'one-shot (comics)': 0.0,
#  'Malibu Comics': 0.0,
#  'Incarnation': 0.0,
#  'Mike Conroy (writer)': 0.0,
#  'US Army': 0.0,
#  'Korea': 0.0,
#  'ruby': 0.0,
#  'cave-in': 0.0,
#  'mutant (Marvel Comics)': 0.0007685433786945208,
#  'Warren Worthington III': 0.0007685433786945208,
#  'telepath': 0.0006168421804139976,
#  'Cyclops (Marvel Comics)': 0.0007685433786945208,
#  'Jean Grey': 0.002356545432797229,
#  ':wikt:Astral': 0.0,
#  'Parallel universe (fiction)': 0.0,
#  'cosmic entity (Marvel Comics)': 0.0,
#  'Eternity (comics)': 0.0,
#  'Hulkbusters': 0.0,
#  'Banshee (comics)': 0.0,
#  'vibranium': 0.0004885090293999522,
#  'Spider-Woman (Jessica Drew)': 0.0022437909412974357,
#  'psychic': 0.0,
#  'Madame Web': 0.002341238599934758,
#  'Nothing Can Stop the Juggernaut!': 0.0,
#  'Colossus (comics)': 0.0034162147911283394,
#  'Sentinel (comics)': 0.00044253647251767835,
#  'Nimrod (comics)': 0.0,
#  'Beyonder': 0.0005273833054809173,
#  'Captain Britain': 0.00031972404392680687,
#  'Exemplars (comics)': 0.0,
#  'Sammy Par\\xc3\\xa9': 0.00031972404392680687,
#  'Alpha Flight': 0.002097120835680165,
#  'Mojo (comics)': 0.00031972404392680687,
#  'Excalibur (comics)#New Excalibur (2005\\xe2\\x80\\x932007)': 0.0,
#  'World War Hulk': 0.0005870712260284867,
#  'Skaar (comics)': 0.0,
#  'The Gauntlet and Grim Hunt': 0.0,
#  'Nothing Can Stop the Juggernaut!#Something Can Stop the Juggernaut': 0.0,
#  'Captain Universe': 0.0,
#  'Siege (comics)': 0.0,
#  'Serpent (comics)': 0.0,
#  'Vanisher': 0.0,
#  'Man-Killer': 0.0,
#  'Living Monolith': 0.0,
#  'All-New X-Men': 0.0,
#  'force shield': 0.0,
#  'invulnerability': 0.0,
#  'Shatterstar': 0.00031972404392680687,
#  'Mjolnir (Marvel Comics)': 0.0,
#  'telepathy': 0.00031972404392680687,
#  'Capeline': 0.0,
#  'Rachel Summers': 0.00031972404392680687,
#  'Days of Future Past': 0.0,
#  'File:Ultjugg.jpg': 0.0,
#  'Ultimate X-Men Annual': 0.0,
#  'Tom Raney': 0.0,
#  'Ultimate X-Men': 0.00031972404392680687,
#  'Weapon X#Ultimate Marvel Universe': 0.0,
#  'Rogue (comics)#Ultimate Rogue': 0.0,
#  'trailer park': 0.0,
#  'Kestrel (Marvel Comics)': 0.0,
#  'Brotherhood of Mutants': 0.0010212731490579087,
#  'Gambit (comics)': 0.00031972404392680687,
#  'Ultimatum (Ultimate Marvel)': 0.0,
#  'William Stryker': 0.00044253647251767835,
#  'Marvel Apes': 0.0,
#  'William Marshall (film and television actor)': 0.0,
#  'Bob Holt (actor)': 0.0,
#  'The Incredible Hulk (1982 TV series)': 0.0,
#  'X-Men: Pryde of the X-Men': 0.0,
#  'Ron Gans': 0.0,
#  'Fantastic Four (1994 TV series)': 0.0,
#  'X-Men: Evolution': 0.0,
#  'Paul Dobson (actor)': 0.0,
#  'Mystique (comics)': 0.0010212731490579087,
#  'Cerebro': 0.0,
#  'X-Mansion': 0.0007157613176978614,
#  'Magneto (comics)': 0.0038866260766389393,
#  'Tildie Soames': 0.0,
#  'Tom Kenny': 0.0,
#  'Black Panther (TV series)': 0.0,
#  'Peter Lurie': 0.0,
#  'Klaw (Marvel Comics)': 0.0,
#  'Kevin Michael Richardson': 0.0,
#  'Awesome Android': 0.0,
#  'Swarm (comics)': 0.0,
#  'Squirrel Girl': 0.0,
#  'Arnim Zola': 0.0008436352866441336,
#  'Rhino (comics)': 0.0005273833054809173,
#  'File:Juggsmovie.PNG': 0.0,
#  'X-Men (film)': 0.00044253647251767835,
#  'Andrew Kevin Walker': 0.0,
#  'Kitty Pryde': 0.0,
#  'Leech (comics)': 0.0,
#  'X-Men: Days of Future Past': 0.0,
#  'Josh Helman': 0.0,
#  'Motion capture': 0.0,
#  'David Leitch (director)': 0.0,
#  'Mister Sinister': 0.0,
#  'LJN': 0.0,
#  'Nintendo Entertainment System': 0.0,
#  'The Uncanny X-Men (video game)': 0.0,
#  'Data East': 0.0,
#  'Captain America and The Avengers': 0.0,
#  'X-Men (arcade game)': 0.0,
#  'arcade game': 0.0,
#  'Konami': 0.0,
#  'Apocalypse (comics)': 0.0,
#  'Wolverine (character)': 0.003457809946447214,
#  "Spider-Man and the X-Men in Arcade\\'s Revenge": 0.0,
#  'All Media Network#AllGame': 0.0,
#  'X-Men (1993 video game)': 0.0,
#  'Danger Room': 0.00031972404392680687,
#  'X-Men: Mutant Apocalypse': 0.0,
#  'Capcom': 0.00044253647251767835,
#  'fighting game': 0.0,
#  'X-Men: Children of the Atom (video game)': 0.0010212731490579087,
#  'Marvel Super Heroes (video game)': 0.0,
#  'Marvel vs. Capcom': 0.0,
#  'X-Men vs. Street Fighter': 0.0,
#  'Marvel vs. Capcom: Clash of Super Heroes': 0.0,
#  'Marvel vs. Capcom 2: New Age of Heroes': 0.0010212731490579087,
#  'X-Men: Mutant Academy 2': 0.0,
#  'X-Men: Next Dimension': 0.0,
#  "X2: Wolverine\\'s Revenge": 0.0,
#  'X-Men Legends': 0.0,
#  'John DiMaggio': 0.0,
#  'X-Men Legends II: Rise of Apocalypse': 0.0,
#  'X-Men: The Official Game': 0.00044253647251767835,
#  'Marvel: Ultimate Alliance 2': 0.0,
#  'GameStop': 0.0,
#  'Spider-Man: Shattered Dimensions': 0.0,
#  'Matt Willig': 0.0,
#  'Marvel Super Hero Squad Online': 0.0,
#  'Travis Willingham': 0.0,
#  'X-Men: Destiny': 0.0007685433786945208,
#  'Marvel Heroes (video game)': 0.0007685433786945208,
#  'Lego Marvel Super Heroes': 0.00044253647251767835,
#  'Andrew Kishino': 0.00044253647251767835,
#  'Star Trek': 0.0,
#  'Planet X (Star Trek)': 0.0,
#  'holodeck': 0.0,
#  'USS Enterprise (NCC-1701-E)': 0.0,
#  'Unus the Untouchable': 0.0,
#  'Worf': 0.0,
#  'overdubbing': 0.0,
#  'List of X-Men episodes': 0.0,
#  'slang': 0.0,
#  'profanity': 0.0,
#  'Non sequitur (literary device)': 0.0,
#  'YouTube': 0.0,
#  'internet meme': 0.0,
#  'MTV News': 0.0,
#  'sequel': 0.0,
#  'Call of Duty: Modern Warfare 2': 0.0,
#  'Achievement (video gaming)': 0.0,
#  'List of incarnations of Spider-Man': 0.07014769930541506,
#  'ai apaec': 0.0,
#  'Moche culture': 0.0,
#  'Marvel Universe': 0.0002318211288140952,
#  'Osborn (comic book)': 0.0,
#  'Limited series (comics)': 0.0018545953618544844,
#  'Kelly Sue DeConnick': 0.0,
#  'Jamie McKelvie': 0.0,
#  'Chimera (mythology)': 0.0,
#  'spider': 0.0,
#  'snake': 0.0,
#  'Moche (culture)': 0.0,
#  'South America': 0.0,
#  'Peru': 0.0,
#  'June Covington': 0.0,
#  'Kingmaker (comics)': 0.0,
#  'Spider-Island': 0.0,
#  'Shang-Chi': 0.0015723565624603875,
#  'Iron Fist (comics)': 0.0,
#  'Immortal Weapons': 0.0,
#  'Barney Barton': 0.0,
#  'Gorgon (Tomi Shishido)': 0.0,
#  'Skaar (character)': 0.0,
#  'Superia': 0.0,
#  'U.S. Agent (comics)': 0.0,
#  'Clea': 0.0005889251504686229,
#  'diving bell spider': 0.0,
#  'Spider-Verse': 0.0006922605944826395,
#  'Karn (comics)': 0.00037154886338060944,
#  'Spider-Man Unlimited (video game)': 0.0012476508141899482,
#  'Dying Wish': 0.0,
#  'Scarlet Spider': 0.0,
#  'Spidercide': 0.0,
#  'Blood Spider': 0.0,
#  'Jagged Bow': 0.0,
#  'Death-Shield': 0.0,
#  'Flash Thompson#Venom': 0.0,
#  'List of Venom titles': 0.0,
#  'Doppelganger (comics)': 0.0,
#  'Magus (comics)': 0.0,
#  'the Infinity War': 0.0,
#  'Ezekiel (comics)': 0.0,
#  'the Spider Society': 0.0,
#  'Tarantula (Marvel Comics)': 0.0006205119829703986,
#  'Steel Spider': 0.0,
#  'The Electric Company': 0.0,
#  'Julia Carpenter': 0.00037154886338060944,
#  'Spider-Woman (Mattie Franklin)': 0.0,
#  'Spider-Woman (Charlotte Witter)': 0.0,
#  'Anya Corazon': 0.0,
#  'Latina': 0.0,
#  'Latino-American': 0.0,
#  'Silk (comics)': 0.0,
#  'Korean-American': 0.0,
#  'Kang the Conqueror': 0.0002318211288140952,
#  'Marvel Team-Up': 0.0004113283202407659,
#  'List of Spider-Man enemies': 0.0,
#  'Kraven the Hunter': 0.0,
#  'Earth 616': 0.0,
#  'Miek': 0.02748161463304994,
#  'Thor: Ragnarok': 0.0,
#  'Planet Hulk': 0.0,
#  'Greg Pak': 0.0006342061049916756,
#  'Carlo Pagulayan': 0.0,
#  'insectoid': 0.0,
#  'Red King (Marvel Comics)': 0.0,
#  'Hiroim': 0.0,
#  'Caiera': 0.0,
#  'No-Name': 0.0,
#  'hermaphrodite': 0.0,
#  'Marvel Zombies Return': 0.0,
#  'Giant Man': 0.0,
#  'List of What If issues#Volume six (2007)': 0.0,
#  'Dave Wittenberg': 0.0,
#  'Hulk and the Agents of S.M.A.S.H.': 0.0,
#  'Benjamin Diskin': 0.0,
#  'Planet Hulk (film)': 0.00019823815812493076,
#  'Samuel Vincent': 0.0,
#  'Valkyrie (Marvel Comics)': 0.000534375501359607,
#  'Kevin Feige': 0.0,
#  'Marvel Contest of Champions': 0.0,
#  'Warbound': 0.0,
#  'Mondo (comics)': 0.023605401801224363,
#  'comic book': 0.0,
#  'Generation X (comics)': 0.0,
#  'cloning': 0.0,
#  'Samoans': 0.0,
#  'Cordelia Frost': 0.0,
#  'Emma Frost': 0.0015793932640267006,
#  'Hellfire Club (comics)': 0.0001661432764684273,
#  'simulacrum': 0.0,
#  'Jubilee (comics)': 0.0005286274500284,
#  'Bastion (comics)': 0.0,
#  'Operation: Zero Tolerance': 0.0,
#  'Image:gennext3.jpg': 0.0,
#  'Shadowcat': 0.0,
#  'Sugar Man': 0.0,
#  'Magik (comics)': 0.00029454338458087965,
#  'Bishop (comics)': 0.0,
#  'illeism': 0.0,
#  'Generation X (film)': 0.0,
#  'Bumper Robinson': 0.0,
#  'Jello': 0.0,
#  'Nomad (comics)': 0.03310484434987757,
#  'Grand Director': 0.0,
#  'Demolition Man (comics)': 0.0,
#  'Bucky (Marvel Comics)': 0.0,
#  'Scourge (comics)': 0.0,
#  'Steve Englehart': 0.0,
#  'Steve Rogers (comics)': 0.0,
#  'Jack Monroe (comics)': 0.0,
#  'Rikki Barnes': 0.0,
#  'Image:CaptainAmericaV1-180.jpg': 0.0,
#  'Gil Kane': 0.0,
#  'United States government': 0.0,
#  'President of the United States': 0.0,
#  'Richard Nixon': 0.0,
#  'Secret Empire (organization)': 0.0,
#  'Golden Archer': 0.0,
#  'Ameridroid': 0.0,
#  'Onslaught Reborn': 0.0,
#  'Young Avengers': 0.0,
#  'Patriot (comics)#Patriot (Eli Bradley)': 0.0,
#  'Sean McKeever': 0.0,
#  'David Baldeon': 0.0,
#  'Newsarama': 0.0,
#  'Sharon Carter': 0.0,
#  'AXIS (comics)': 8.592848550517287e-05,
#  'Northstar (Marvel Comics)': 0.15960242866164556,
#  'Chris Claremont': 0.0003630823366685834,
#  'Uncanny X-Men': 0.0003630823366685834,
#  'Canadians': 0.0,
#  'photonics': 0.0,
#  'Aurora (comics)': 0.0,
#  'homosexuality': 0.0,
#  'Astonishing X-Men': 0.0,
#  'same-sex wedding': 0.0,
#  'Alpha Flight (comic book)': 0.0,
#  'Jim Shooter': 0.0,
#  'Comics Code Authority': 0.0,
#  'Jackson, Mississippi': 0.0,
#  'Bill Mantlo': 0.0,
#  'AIDS': 0.0,
#  'Scott Lobdell': 0.0,
#  'Comic Book Resources': 0.0011554824791841338,
#  'The Advocate (LGBT magazine)': 0.0,
#  'The New York Times': 0.0,
#  'Gaylactic Spectrum Awards#Hall of Fame': 0.0,
#  'AfterElton.com': 0.0,
#  'Pantheon (Marvel Comics)': 0.0,
#  'Hector (Pantheon)': 0.0,
#  'continuity (fiction)': 0.0,
#  'X-Men: The End': 0.0,
#  'alternate timeline': 0.0,
#  'Perry Moore': 0.0,
#  'Hero (novel)': 0.0,
#  'Iceman (comics)': 0.0,
#  'Chuck Austen': 0.0,
#  'Sean Phillips': 0.0,
#  'Anole (comics)': 0.0,
#  'Jeff Parker (comics)': 0.0,
#  'Fred Van Lente': 0.0,
#  'Ariel Olivetti': 0.0,
#  'One Million Moms': 0.0,
#  'Pink Paper': 0.0,
#  'French Canadian': 0.0,
#  'Montreal': 0.0,
#  'Front de lib\\xc3\\xa9ration du Qu\\xc3\\xa9bec': 0.0,
#  'terrorism': 0.0,
#  'Quebec': 0.0,
#  'Canada': 0.0,
#  'multiple personality disorder': 0.0,
#  'Deadly Ernest#Deadly Ernest (Ernest St. Ives)': 0.0,
#  'Sasquatch (comics)': 0.0,
#  'Pestilence (comics)': 0.0,
#  'File:Northstar (X-Men).png': 0.0,
#  'Salvador Larroca': 0.0,
#  'HIV': 0.0,
#  'X-Men: Eve of Destruction': 0.0,
#  'Genosha': 0.0006514358297619102,
#  'Omerta (comics)': 0.0,
#  'Alpha Squadron (comics)': 0.0,
#  'Annie Ghazikhanian': 0.0,
#  'Dawn of the White Light': 0.0,
#  'Hand (comics)': 0.0,
#  'New Mutants': 0.0012410963535470212,
#  'Elixir (comics)': 0.000328036904312387,
#  'resurrection': 0.0,
#  'Deprogramming': 0.0,
#  'Children of the Vault': 0.0,
#  'Rogue (comics)': 0.000592422135380046,
#  'Virtual reality': 0.0,
#  'Exodus (comics)': 0.0,
#  'Arcs: Divided We Stand, [[Secret Invasion': 0.0,
#  'All-points bulletin': 0.0,
#  'speedster (fiction)': 0.0,
#  'Surge (comics)': 0.0,
#  'Simon Trask': 0.0,
#  'Dark X-Men': 0.0,
#  'Limbo (Marvel Comics)': 0.0,
#  'X-Men: Second Coming': 0.0,
#  'Guardian (Marvel Comics)': 0.0,
#  'Jerry Jaxon': 0.0,
#  'Chaos War (comics)': 0.0008400684275856901,
#  'File:Northstar and Aurora.jpg': 0.0,
#  'sense of balance': 0.0,
#  'candela': 0.0,
#  'Puck (comics)': 0.0,
#  'File:AoANorthstarAurora.png': 0.0,
#  ...}

# %% [markdown]
# > **Ex: 6.2.6**: Create yet another similar bar chart where instead you measure the [local clustering coefficient](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.clustering.html#networkx.algorithms.cluster.clustering) (CC).
# * Explain briefly what the CC measures, and what it intuitively means that a node is highly clustered (CC=1) or not clustered at all (CC=0).
# * Interpret the difference between classes.

# %% [markdown]
# > **Extra: Ex: 6.2**: There seems to be some correlation between BC, degree and clustering, but it definitely doesn't look perfect. Try to make a scatter plot of characters' degree vs. their BC. If time permits, pimp your plot by:
# * Prettifying your plot by:
#     * Setting appropriate axis limits and labels
#     * Fontsizes, figure title, etc.
#     * Adding a slight amount of *jitter* to the degree
# * Coloring nodes by class (hero: blue, villain: red, ambiguous: yellow)
# * Scaling node sizes by the CC (add an offset so no nodes have size 0).
#
# > Highlight your findings:
# * Which characters have an unusually high centrality compared to their degree and vice versa? How can you explain this?
# * Does this inspire you to think about new things that can be investigated?

# %% [markdown]
# > **Ex: 6.2.7**: We want to plot the network so we can visually get a feeling for how characters are connected. However, the network is too big to plot without some kind of pre-processing. Therefore, we remove all links between nodes that are not on the top 10 list of high-degree characters within their class.
# * Color the nodes by class. Try if you can to use blue for heroes, red for villains and yellow for ambiguous.
# * Scale the size of nodes by the square root of their degree.
# * Adjust the layout of the figure so it doesn't look too messy (e.g. edge line width, node line width, type of force-layout [I can recommend *neato*, but you have to install graphviz with conda to use it])
# * Do you see anything interesting? Get any new ideas for things that can be investigated?
#
# > *Hint: I actually made [a tool](https://ulfaslak.com/works/network_styling_with_d3/index.html) for making pretty visualizations of networks. I'd be curious to see the Marvel network visualized in my tool.*
