# %% [markdown]
# # Week 6: Networks

# %% [markdown]
# A network is a way to represent a system of things that interact or are interrelated in some fashion. It could just be your facebook network, that's obvious, but a network can also represent the interaction patterns of proteins in the human body, who votes what on whose bill in the US Senate, the mutually attractive forces between galaxies in the universe or just about anything else that you can possibly imagine. This week we are going to study how characters in the Marvel universe relate to each other using networks. In the exercises today you will:
#
# * Get warmed up to thinking about systems as networks
# * Learn to use the `NetworkX` library
# * Explore the partnership network of the Marvel dataset

# %% [markdown]
# [**Questions**](https://github.com/ulfaslak/computational_analysis_of_big_data_2018_fall/issues) **/** [**Feedback**](https://ulfaslak.com/vent)

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Part 0: Networks

# %% [markdown]
# Questions for chapter 1 and 2 of [Network Science](http://barabasi.com/networksciencebook/).

# %% [markdown]
# > **Ex. 6.0.1**: List three different real networks and state the nodes and links for each of them.

# %% [markdown]
# > **Ex. 6.0.2**: What networks are you personally most interested in. Address the following questions:
# >   * What are its nodes and links?
# >   * How large is it?
# >   * Can be mapped out?
# >   * Why do you care about it?

# %% [markdown]
# WikiPedia pages.
# * Nodes are WikiPedia webpages, edges are the links to other Wikipedia pages in that page
# * It is massive
# * Yes
# * It's interesting

# %% [markdown]
# > **Ex. 6.0.3**: In your view what would be the area where network science could have the biggest impact in the next decade? Explain your answer - and base it on the text in the book.

# %% [markdown]
# Advertising.

# %% [markdown]
# > **Ex. 6.0.4**: Section 2.5 states that real networks are sparse. Can you think of a real network where each node has *many* connections? Is that network still sparse? If yes, can you explain why?

# %% [markdown]
# ### Part 1: The `NetworkX` library

# %% [markdown]
# `NetworkX` is the Python library we will be using for working with networks. It should come installed with your Anaconda distribution, but you wont know how to use it yet. The best way to get familiar is to work through a tutorial. That's what the following exercises are about.

# %% [markdown]
# > **Ex. 6.1.1**: Go to the `NetworkX` project's [tutorial page](https://networkx.github.io/documentation/stable/tutorial.html). Read the first few sections about nodes, edges and attributes. Write an example below where you create a graph, `G`, and then:
# 1. add some nodes and edges to,
# 2. print its nodes and edges
# 3. delete a node, and
# 4. plot it.

# %%
import os
import re
import requests as rq
import pandas as pd
import numpy as np
import urllib3 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)  # Suppress InsecureRequestWarning

def get_marvel_character_list(character_type):
    """Returns a set of one type of Marvel Characters (either superheroes or supervillains)
    
    Using the rq.get() method, request the WikiPedia page containing the list of either character type
    defined by the user, then store the .json result into a dictionary, with the continue keyword if it 
    exists. In a loop, keys into query and categorymembers to access title, which contains the character
    name to be added into a set, requests another query with the continue key. If there is a KeyError,
    Then there is no more continue data to be keyed into.
    
    Args:
        characters: string describing the type of marvel characters ("superheroes or supervillains")
        
    Returns: 
        list: a set of the character names
    """
    
    group = set()  
    
    wpage = r"https://en.wikipedia.org/w/api.php?"
    action = r"action=query"
    format = r"format=json"
    list = r"list=categorymembers"
    title = r"cmtitle=Category:Marvel_Comics_%s" % character_type
    url = wpage + "&".join([action,format,list,title])
    
    data = rq.get(url).json()
    cont = data['continue']['cmcontinue']
    
    for entry in data['query']['categorymembers']:
        group.add(entry['title'])
    while True:
        try:
            data = rq.get(url + "&cmcontinue=%s" % cont).json()
            cont = data['continue']['cmcontinue']

            for entry in data['query']['categorymembers']:
                group.add(entry['title'])
        except KeyError:
            break
    return group

def make_groups(**offline):
    """Partitions the three main groups
    
    Defines global variables for each then makes the superheroes and supervillain
    sets. If offline, the markups are already stored on the directory, so to make
    the groups, just make a set of list of files in each directory. Else, forms the 
    superheroes and supervillains from requests (takes long) and  forms the ambiguous 
    set which is the intersection then, subtracts them from each group.
    
    Args:
        offline: a keyword argument specifying if the groups should be made from 
        the existing directory or from requesting. The former is much faster as it
        just accesses the already-stored markups on each of the character folders,
        instead of requesting all over again.
    Returns:
        a tuple of superheroes, supervillains, ambiguous in that order.
    """
    
    def clean_data(data):
        """Cleans the set by removing entries with 'Category' or 'List of'."""
        for item in data.copy():
            if item.find("Category") != -1 or item.find("List of") != -1:
                data.remove(item)
        return data
    
    global superheroes, supervillains, ambiguous
    
    if offline:  # Must have the the stored directory hierarchy already.
        for group, faction in enumerate(['superheroes', 'supervillains', 'ambiguous']):  # Each file has a .txt extension
            faction_chars = [c[:-4] for c in os.listdir('characters/%s' % faction)]      # So splice each until [:-4]
            
            if group == 0:
                superheroes = clean_data(faction_chars)
                
            elif group == 1:
                supervillains = clean_data(faction_chars)
            
            elif group == 2:
                ambiguous = clean_data(faction_chars)
        
    else:          
        superheroes = get_marvel_character_list("superheroes")
        supervillains = get_marvel_character_list("supervillains")
        ambiguous = superheroes.intersection(supervillains)
        superheroes -= ambiguous
        supervillains -= ambiguous
        
    return superheroes, supervillains, ambiguous

superheroes, supervillains, ambiguous = make_groups(offline=True)

# %%
plt.style.use('dark_background')

G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(2,5),(5,4),(3,2),(4,1)])
plt.subplot(1,2,1)
nx.draw(G, with_labels=True)

G.remove_node(2)
plt.subplot(1,2,2)
nx.draw(G)

plt.show()

# %% [markdown]
# > **Ex. 6.1.2**: `NetworkX` has lots of functions to generate synthetic networks. One of the most famous types of synthetic networks is called an Erdős–Rényi (ER) network.
# 1. Describe how to create an ER network.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-2.2/reference/generators.html), find a method you can use for generating an ER network. Create one with $N=100$ nodes and probability of edge creation $p=0.1$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created ER graph.
#     * A node's *degree* is the number of other nodes it is connected to.
#     * The *degree distribution* is a histogram which shows the distribution of node degrees.

# %%
#2.
er = nx.fast_gnp_random_graph(100,0.1)

#3.
ax1 = plt.figure(figsize=(15,15))
nx.draw(er)

#4
def get_degrees(graph):
    degrees = []
    for x, y in graph.adj.items():
        degrees.append(len(y.keys()))
    return degrees

er_degrees = get_degrees(er)

ax2 = plt.figure(figsize=(5,5))
plt.hist(er_degrees)
plt.xlabel("Degrees")
plt.title("Distribution of the ER Graph degrees")


plt.show()

# %% [markdown]
# > **Ex. 6.1.3**: Another very famous type of synthetic network is the Barabási–Albert (BA) network.
# 1. Describe what a BA network is and how to create one.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-2.2/reference/generators.html), find a method you can use for generating a BA network. Create one with $N=100$ nodes and number of new edges from each new node $m=2$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created BA graph.
# 5. Explain the main difference(s) you observe, when comparing to the ER network.
# 6. Are there other measures we could have used to describe the ER and BA networks further?

# %%
#2
ba = nx.barabasi_albert_graph(100,2)

#3
ax3 = plt.figure(figsize=(15,15))
nx.draw(ba)

#4
ba_degrees = get_degrees(ba)
ax4 = plt.figure(figsize=(5,5))
plt.hist(ba_degrees)
plt.xlabel("Degrees")
plt.title("Distribution of the BA Graph degrees")

plt.show()

#5
"""
The distribution of the ER Graph is a bell distribution, while the BA Graph is tail-heavy
"""
# Out:
# '\nThe distribution of the ER Graph is a bell distribution, while the BA Graph is tail-heavy\n'

# %% [markdown]
# ### Part 2: Marvel character partners

# %% [markdown]
# Now that you know how to build a network in `NetworkX`, visualize it and plot some statistics, you are ready to analyze our Marvel dataset. The aim of the following exercises is to analyze the network *partnerships* between characters.

# %% [markdown]
# > **Ex. 6.2.1**: Write a function called `get_partners` that takes a character name, and extracts a list of their partners. Print the partnerships of Iron Man. They should be `['War Machine', 'Pepper Potts', 'Riri Williams']`.
#
# >*Hint: Partnerships for a character are listed in the same way that alliances are. You can probably save yourself some time by looking at your solution to Ex. 4.1.1. Especially if you made use of regular expressions.*

# %%
all_heroes = sorted(superheroes + supervillains + ambiguous)

# %%
all_heroes
# Out:
# ['Abdul Alhazred (comics)',
#  'Abigail Brand',
#  'Abner Jenkins',
#  'Abomination (comics)',
#  'Abraham Cornelius',
#  'Absalom (comics)',
#  'Absorbing Man',
#  'Abyss (comics)',
#  'Achilles (Pantheon)',
#  'Acrobat (comics)',
#  'Adam II',
#  'Adam Warlock',
#  'Adam X the X-Treme',
#  'Adept (comics)',
#  'Adonis (comics)',
#  'Adrenazon',
#  'Adria (comics)',
#  'Adrienne Frost',
#  'Adversary (comics)',
#  'Advisor (comics)',
#  'Aegis (Lady of All Sorrows)',
#  'Aftershock (comics)',
#  'Agent (comics)',
#  'Agent Axis',
#  'Agent X (Marvel Comics)',
#  'Agron (comics)',
#  'Aguja',
#  'Ahab (comics)',
#  'Ahura (comics)',
#  'Aikku Jokinen',
#  'Air-Walker',
#  'Airborne (comics)',
#  'Ajax (comics)',
#  'Ajaxis',
#  'Al MacKenzie',
#  'Al-Tariq',
#  'Alaris (comics)',
#  'Albert (comics)',
#  'Albino (comics)',
#  'Aldebron',
#  'Aldrich Killian',
#  'Aleksander Lukin',
#  'Aleta Ogord',
#  'Alex (comics)',
#  'Alex Wilder',
#  'Alexander Bont',
#  'Alice Nugent',
#  'Alistair Smythe',
#  'Allatou',
#  'Alpha (Marvel Comics)',
#  'Alpha the Ultimate Mutant',
#  'Alternative versions of Magneto',
#  'Amadeus Cho',
#  'Amanda Sefton',
#  'Amatsu-Mikaboshi (comics)',
#  'Amelia Voght',
#  'American Ace',
#  'American Dream (comics)',
#  'American Eagle (Marvel Comics)',
#  'American Samurai',
#  'Americop',
#  'Aminedi',
#  'Ammo (comics)',
#  'Amphibion',
#  'Amphibius (comics)',
#  'Anaconda (comics)',
#  'Andrew Forson',
#  'Andromeda (Marvel Comics)',
#  'Angel (Thomas Halloway)',
#  'Angel Dust (comics)',
#  'Angel Salvadore',
#  'Angela (comics)',
#  'Ani-Mator',
#  'Animus (Marvel Comics)',
#  'Anne Weying',
#  'Anne-Marie Cortez',
#  'Annex (comics)',
#  'Annihilus',
#  'Anole (comics)',
#  'Answer (comics)',
#  'Ant-Man (Scott Lang)',
#  'Anthem (comics)',
#  'Anya Corazon',
#  'Ape-Man',
#  'Ape-X',
#  'Apocalypse (Marvel Comics)',
#  'Apocalypse Twins',
#  'Aquarius (Marvel Comics)',
#  'Aqueduct (comics)',
#  'Aquon',
#  'Arabian Knight (comics)',
#  'Aragorn (comics)',
#  'Arcade (Marvel Comics)',
#  'Arcadia (comics)',
#  'Archer (Marvel Comics)',
#  'Arclight (comics)',
#  'Ardina',
#  'Ares (Marvel Comics)',
#  'Aries (comics)',
#  'Armadillo (comics)',
#  'Armageddon (Marvel Comics)',
#  'Armless Tiger Man',
#  'Armor (comics)',
#  'Armory (comics)',
#  'Arnold Roth (Captain America)',
#  'Aron (comics)',
#  'Arsenal (Marvel Comics)',
#  'Asbestos Man',
#  'Asmodeus (Marvel Comics)',
#  'Asp (comics)',
#  'Astra (Imperial Guard)',
#  'Athena (Marvel Comics)',
#  'Attuma',
#  'Auntie Freeze',
#  'Auric (comics)',
#  'Aurora (comics)',
#  'Avalanche (comics)',
#  'Awesome Android',
#  'Azazel (Marvel Comics)',
#  'Backhand (comics)',
#  'Balder (comics)',
#  'Balor (comics)',
#  'Banshee (comics)',
#  'Baphomet (comics)',
#  'Barnell Bohusk',
#  'Barney Barton',
#  'Baron Blood',
#  'Baron Brimstone',
#  'Baron Mordo',
#  'Baron Samedi (comics)',
#  'Baron Strucker',
#  'Baron Von Blitzschlag',
#  'Baron Zemo',
#  'Base (comics)',
#  'Basilisk (comics)',
#  'Bastion (comics)',
#  'Batroc the Leaper',
#  'Battering Ram (comics)',
#  'Battlestar (comics)',
#  'Batwing (Marvel Comics)',
#  'Baymax',
#  'Beast (comics)',
#  'Bedlam (comics)',
#  'Beef (comics)',
#  'Beetle (comics)',
#  'Bela (comics)',
#  'Belasco (Marvel Comics)',
#  'Bella Donna (comics)',
#  'Ben Reilly',
#  'Benedict Kine',
#  'Bengal (comics)',
#  'Bereet',
#  'Beta Ray Bill',
#  'Beyonder',
#  'Bi-Beast',
#  'Big Bertha (comics)',
#  'Big Man (comics)',
#  'Big Wheel (comics)',
#  'Bill Foster (comics)',
#  'Bird-Brain (Marvel Comics)',
#  'Bird-Man',
#  'Birdy (comics)',
#  'Bison (comics)',
#  'Black Bolt',
#  'Black Box (comics)',
#  'Black Cat (Marvel Comics)',
#  'Black Crow (comics)',
#  'Black Dwarf (comics)',
#  'Black Fox (Raul Chalmers)',
#  'Black Fox (Robert Paine)',
#  'Black Jack Tarr',
#  'Black Knight (Dane Whitman)',
#  'Black Knight (Nathan Garrett)',
#  'Black Knight (Sir Percy)',
#  'Black Knight (comics)',
#  'Black Lama',
#  'Black Mamba (comics)',
#  'Black Mariah (comics)',
#  'Black Marvel',
#  'Black Panther (comics)',
#  'Black Racer (Marvel Comics)',
#  'Black Rider (comics)',
#  'Black Spectre',
#  'Black Swan (comics)',
#  'Black Talon (Samuel Barone)',
#  'Black Talon (comics)',
#  'Black Tarantula',
#  'Black Tom Cassidy',
#  'Black Widow (Claire Voyant)',
#  'Black Widow (Marvel Comics)',
#  'Black Widow (Natasha Romanova)',
#  'Black Widow (Yelena Belova)',
#  'Blackbird (Femizon)',
#  'Blackheart',
#  'Blacklight (MC2)',
#  'Blackout (Lilin)',
#  'Blackout (Marcus Daniels)',
#  'Blackthorn (comics)',
#  'Blackwing',
#  'Blackwulf',
#  'Blade (comics)',
#  'Blank (comics)',
#  'Blastaar',
#  'Blazing Skull',
#  'Blindfold (comics)',
#  'Bling!',
#  'Blink (comics)',
#  'Bliss (Marvel Comics)',
#  'Blizzard (comics)',
#  'Blob (comics)',
#  'Bloke (comics)',
#  'Blonde Phantom',
#  'Blood Brothers (comics)',
#  'Bloodaxe (comics)',
#  'Bloodhawk',
#  'Bloodlust (comics)',
#  'Bloodscream',
#  'Bloodshed (comics)',
#  'Bloodstrike (Marvel Comics)',
#  'Blue Blade',
#  'Blue Diamond (comics)',
#  'Blue Eagle (comics)',
#  'Blue Ear',
#  'Blue Marvel',
#  'Blue Shield (comics)',
#  'Blue Streak (comics)',
#  'Bob Diamond (comics)',
#  'Bob, Agent of Hydra',
#  'Bobcat (comics)',
#  'Bolivar Trask',
#  'Bombshell (Marvel Comics)',
#  'Bonebreaker',
#  'Boobytrap (comics)',
#  'Boomerang (comics)',
#  'Boomslang (comics)',
#  'Boost (comics)',
#  'Bounty Hunter (comics)',
#  'Box (comics)',
#  'Brain Drain (comics)',
#  'Brain-Child',
#  'Brainchild (comics)',
#  'Breeze Barton',
#  'Brent Jackson',
#  'Bres (comics)',
#  'Brian Banner',
#  'Brother Tode',
#  'Brother Voodoo',
#  'Brothers Grimm (comics)',
#  'Brute (Morlocks)',
#  'Brute (Reed Richards)',
#  'Brynocki',
#  'Bryson Bale',
#  'Bucky (Marvel Comics)',
#  'Bucky Barnes',
#  'Bug (comics)',
#  'Bulldozer (Marvel Comics)',
#  'Bulldozer (comics)',
#  'Bullet (comics)',
#  'Bullet Biker (comics)',
#  'Bullseye (comics)',
#  'Bulwark (comics)',
#  'Burner (comics)',
#  'Burstaar (comics)',
#  'Bushman (comics)',
#  'Bushmaster (Marvel Comics)',
#  'Bushwacker (comics)',
#  'Buzz (comics)',
#  'Byrrah',
#  'Cable (comics)',
#  'Cadena (comics)',
#  'Caiera',
#  'Caiman (comics)',
#  'Caliban (Marvel Comics)',
#  'Callisto (comics)',
#  'Calypso (comics)',
#  'Cameron Hodge',
#  'Cammi',
#  'Cancer (comics)',
#  'Candra (comics)',
#  'Cannonball (comics)',
#  'Capricorn (comics)',
#  'Captain (comics)',
#  'Captain America',
#  'Captain America (William Burnside)',
#  'Captain Americana',
#  'Captain Atlas',
#  'Captain Britain',
#  "Captain Marvel (Khn'nr)",
#  'Captain Marvel (Marvel Comics)',
#  'Captain Midlands',
#  'Captain Omen',
#  'Captain Ultra',
#  'Captain Universe',
#  'Cardiac (comics)',
#  'Cardinal (comics)',
#  'Caretaker (comics)',
#  'Carnage (comics)',
#  'Carol Danvers',
#  'Carrion (comics)',
#  'Cassandra Lang',
#  'Cassandra Nova',
#  'Cat-Man (Marvel Comics)',
#  'Catseye (comics)',
#  'Cecilia Reyes',
#  'Centurious',
#  'Centurius',
#  'Cerebra',
#  'Cerise (comics)',
#  "Ch'od",
#  'Chaka (comics)',
#  'Challenger (comics)',
#  'Chamber (comics)',
#  'Chameleon (comics)',
#  'Champion of the Universe',
#  'Chance (comics)',
#  'Charcoal (comics)',
#  'Charlie-27',
#  'Charlotte Jones (comics)',
#  'Charon (Marvel Comics)',
#  'Chase Stein',
#  'Chemistro',
#  'Cheshire Cat (comics)',
#  'Chimera (Marvel Comics)',
#  'Chondu the Mystic',
#  'Chris Bradley',
#  'Christian Walker',
#  'Chrome (comics)',
#  'Chthon (Marvel Comics)',
#  'Cipher (comics)',
#  'Circuit Breaker (Transformers)',
#  'Citizen V',
#  'Cletus Kasady',
#  'Clive (comics)',
#  'Cloak and Dagger (comics)',
#  'Cloud (comics)',
#  'Cloud 9 (comics)',
#  'Clown (comics)',
#  'Coachwhip (comics)',
#  'Coal Tiger',
#  'Cobalt Man',
#  'Cobra (Marvel Comics)',
#  'Cockroach Hamilton',
#  'Cold War (comics)',
#  'Coldblood',
#  'Collective Man',
#  'Collector (comics)',
#  'Colleen Wing',
#  'Colossus (comics)',
#  'Comanche (comics)',
#  'Comet Man',
#  'Commander Kraken',
#  'Conan (Marvel Comics)',
#  'Condor (comics)',
#  'Constrictor (comics)',
#  'Controller (Marvel Comics)',
#  'Copperhead (Marvel Comics)',
#  'Copycat (Marvel Comics)',
#  'Corruptor',
#  'Corsair (comics)',
#  'Corvus Glaive',
#  'Cottonmouth (Burchell Clemens)',
#  'Cottonmouth (Cornell Stokes)',
#  'Count Nefaria',
#  'Crane Mother',
#  'Crime Master',
#  'Crimson Commando',
#  'Crimson Cowl (Justine Hammer)',
#  'Crimson Curse',
#  'Crimson Dynamo',
#  'Crippler (comics)',
#  'Crossbones (comics)',
#  'Crossfire (comics)',
#  'Crule',
#  'Crusader (Marvel Comics)',
#  'Crusaders (Marvel Comics)',
#  'Crusher (comics)',
#  'Crystal (comics)',
#  'Cullen Bloodstone',
#  'Cutthroat (comics)',
#  'Cyber (Marvel Comics)',
#  'Cyclone (Marvel Comics)',
#  'Cyclops (Marvel Comics)',
#  'Cypher (Marvel Comics)',
#  'Cyttorak',
#  "D'Ken",
#  "D'Spayre",
#  'Dagoth',
#  'Daimon Hellstrom',
#  'Daisy Johnson',
#  'Daken',
#  'Dakota North (comics)',
#  'Dallas Riordan',
#  'Damage (Marvel Comics)',
#  'Damon Dran',
#  'Danger Room',
#  'Daniel Drumm',
#  'Daniel Whitehall',
#  'Danielle Moonstar',
#  'Daredevil (Marvel Comics character)',
#  'Dark Angel (Marvel Comics)',
#  'Dark Beast',
#  'Dark Gods (Marvel Comics)',
#  'Darkdevil',
#  'Darkhawk',
#  'Darkoth',
#  'Darkstar (comics)',
#  'Darren Cross',
#  'Darwin (comics)',
#  'David Moreau',
#  'David North (comics)',
#  'David Sum',
#  'Dazzler (Marvel Comics)',
#  'Deacon (comics)',
#  'Deacon Frost',
#  'Dead Girl',
#  'Deadalus (comics)',
#  'Deadpool',
#  'Death Adder (comics)',
#  'Death Locket',
#  'Death Metal (comics)',
#  "Death's Head",
#  'Death-Shield',
#  'Death-Stalker',
#  'Deathbird',
#  'Deathcry',
#  'Deathlok',
#  'Deathwatch (comics)',
#  'Debrii',
#  'Defensor (comics)',
#  'Delilah (comics)',
#  'Delphyne Gorgon',
#  'Delroy Garrett',
#  'Demogoblin',
#  'Demolition Man (comics)',
#  'Demon Bear',
#  'Desak',
#  'Destiny (Irene Adler)',
#  'Destroyer (Marvel Comics)',
#  'Detroit Steel',
#  'Devastator (comics)',
#  'Devil Dinosaur',
#  'Devil Hulk',
#  'Devil-Slayer',
#  'Devos the Devastator',
#  'Diablo (Marvel Comics)',
#  'Diamanda Nero',
#  'Diamond (comics)',
#  'Diamond Lil (comics)',
#  'Diamondback (Rachel Leighton)',
#  'Diamondback (Willis Stryker)',
#  'Diamondhead (comics)',
#  'Die-Cut (comics)',
#  'Digger (comics)',
#  'Digitek (comics)',
#  'Dinah Soar',
#  'Dire Wraith',
#  'Dirk Anger',
#  'Dirtnap (comics)',
#  'Discus (comics)',
#  'Dittomaster',
#  'Dmitri Bukharin',
#  'Doc Samson',
#  'Doctor Bong',
#  'Doctor Demonicus',
#  'Doctor Doom',
#  'Doctor Druid',
#  'Doctor Faustus (comics)',
#  'Doctor Minerva',
#  'Doctor Nemesis',
#  'Doctor Octopus',
#  'Doctor Spectrum',
#  'Doctor Strange',
#  'Doctor Sun',
#  'Dominic Fortune',
#  'Domino (comics)',
#  'Don Fortunato',
#  'Donald Pierce',
#  'Donyell Taylor',
#  'Doom 2099',
#  'Doombot',
#  'Doomsday Man',
#  'Doop (comics)',
#  'Doorman (comics)',
#  'Doppelganger (comics)',
#  'Dormammu',
#  'Dorrek VII',
#  'Doughboy (comics)',
#  'Dracula (Marvel Comics)',
#  'Dragon Lord (comics)',
#  'Dragon Man',
#  'Dragoness (comics)',
#  'Dragonfly (Marvel Comics)',
#  'Drax the Destroyer',
#  'Dreadknight',
#  'Dreadnought (comics)',
#  'Dreamqueen',
#  'Dredmund the Druid',
#  'Dum Dum Dugan',
#  'Dusk (comics)',
#  'Dust (comics)',
#  'Dweller-in-Darkness',
#  'Earth Lord',
#  'Ebon Samurai',
#  'Ebon Seeker',
#  'Ebony Maw',
#  'Echo (Marvel Comics)',
#  'Ecstasy (comics)',
#  'Eddie Brock',
#  'Eden Fesi',
#  'Eel (comics)',
#  'Egghead (Marvel Comics)',
#  'Ego the Living Planet',
#  'El Aguila',
#  'El Guapo (comics)',
#  'Electro (Marvel Comics)',
#  'Electro (comics)',
#  'Electron (comics)',
#  'Elektro (comics)',
#  'Eli Bard',
#  'Elias Bogan',
#  'Eliminator (comics)',
#  'Elixir (comics)',
#  'Elloe Kaifi',
#  'Elsa Bloodstone',
#  'Elsie-Dee',
#  'Elysius',
#  'Emma Frost',
#  'Emma Steed',
#  'Empath (comics)',
#  'Emplate',
#  'Emrys Killebrew',
#  'Enchantress (Marvel Comics)',
#  'Enforcer (comics)',
#  'Enigma (Marvel Comics)',
#  'Equinox (comics)',
#  'Erg (comics)',
#  "Eric O'Grady",
#  'Erik Josten',
#  'Erik Killmonger',
#  'Erik the Red (comics)',
#  'Ethan Edwards',
#  'Ever (comics)',
#  'Everyman (Marvel Comics)',
#  'Evilhawk',
#  'Executioner (comics)',
#  'Exodus (comics)',
#  'Eyekillers (comics)',
#  'Ezekiel (comics)',
#  'Fabian Cortez',
#  'Fabian Stankowicz',
#  'Fafnir (Marvel Comics)',
#  'Fagin (comics)',
#  'Faiza Hussain',
#  'Falcon (comics)',
#  'Falcona',
#  'Fancy Dan',
#  'Fandral',
#  'Fantomex',
#  'Farley Stillwell',
#  'Fasaud',
#  'Fatale (comics)',
#  'Fenris (comics)',
#  'Fenris Wolf (Marvel Comics)',
#  'Fer-de-Lance (comics)',
#  'Feral (comics)',
#  'Feron',
#  'Fever Pitch (comics)',
#  'Fin (comics)',
#  'Fin Fang Foom',
#  'Finesse (comics)',
#  'Fiona (comics)',
#  'Firebird (Marvel Comics)',
#  'Firebrand (Marvel Comics)',
#  'Firelord (comics)',
#  'Firepower (comics)',
#  'Firestar (Marvel Comics)',
#  'Fixer (comics)',
#  'Fixx',
#  'Flag-Smasher',
#  'Flash Thompson',
#  'Flatman (comics)',
#  'Flex (comics)',
#  'Flipside (comics)',
#  'Flux (comics)',
#  'Flyer (New-Gen)',
#  'Flying Tiger (Marvel Comics)',
#  'Foolkiller',
#  'Forbush Man',
#  'Force (comics)',
#  'Forearm (comics)',
#  'Foreigner (comics)',
#  'Forge (comics)',
#  'Forgotten One (comics)',
#  'Foxfire (comics)',
#  "Frankenstein's Monster (Marvel Comics)",
#  'Franklin Richards (comics)',
#  'Freakmaster',
#  'Freakshow (comics)',
#  'Frederick Foswell',
#  'Frederick Slade',
#  'Fredzilla',
#  'Free Spirit (comics)',
#  'Freedom Ring',
#  "Freedom's Five",
#  'Friedrich Von Roehm',
#  'Fu Manchu (comics)',
#  'Fuego (comics)',
#  'Fury (Marvel Comics)',
#  'Fusion (Marvel Comics)',
#  'Futurist (comics)',
#  'G-Type',
#  'G. W. Bridge',
#  'Gabriel (New-Gen)',
#  'Gabriel the Devil Hunter',
#  'Galactus',
#  'Galaxy Master',
#  'Gambit (comics)',
#  'Gamesmaster (comics)',
#  'Gamora',
#  'Gardener (comics)',
#  'Gargantua (comics)',
#  'Gargoyle (comics)',
#  'Garokk',
#  'Garrison Kane',
#  'Gateway (comics)',
#  'Gauntlet (Inhuman)',
#  'Gauntlet (comics)',
#  'Gazelle (Marvel Comics)',
#  'Gazelle (New-Gen)',
#  'Gazer',
#  'Geiger (comics)',
#  'Geldoff',
#  'Gemini (Marvel Comics)',
#  'Genesis (Marvel Comics)',
#  'Genis-Vell',
#  'Gentle (comics)',
#  'Gentleman (character)',
#  'Geoffrey Wilder',
#  'Gertrude Yorkes',
#  'Ghaur',
#  'Ghost (Marvel Comics)',
#  'Ghost Maker',
#  'Ghost Rider',
#  'Ghost Rider (Danny Ketch)',
#  'Ghost Rider (Johnny Blaze)',
#  'Ghost Rider (Robbie Reyes)',
#  'Ghost Rider 2099',
#  'Ghoul (Ultraverse)',
#  'Giant-Man',
#  'Gibbon (comics)',
#  'Gideon (comics)',
#  'Gideon Mace',
#  'Giganto',
#  'Gilded Lily (character)',
#  'Gin Genie',
#  'Ginniyeh',
#  'Gladiator (Kallark)',
#  'Gladiator (Melvin Potter)',
#  'Gladiatrix (comics)',
#  'Glenn Talbot',
#  'Glob (comics)',
#  'Glob Herman',
#  'Glowworm (comics)',
#  'GoGo Tomago',
#  'Goblin (Marvel Comics)',
#  'Goddess (comics)',
#  'Gog (Marvel Comics)',
#  'Goldballs',
#  'Goldbug (comics)',
#  'Golden Archer',
#  'Golden Girl (Timely Comics)',
#  'Golem (comics)',
#  'Goliath (Marvel Comics)',
#  'Googam',
#  'Gorgilla',
#  'Gorgon (Inhuman)',
#  'Gorgon (Tomi Shishido)',
#  'Gorilla Girl',
#  'Gorilla-Man',
#  'Gosamyr',
#  'Grace (Marvel Comics)',
#  'Grandmaster (Marvel Comics)',
#  'Grappler (comics)',
#  'Grasshopper (comics)',
#  'Graviton (comics)',
#  'Gravity (comics)',
#  'Graydon Creed',
#  'Graymalkin',
#  'Green Goblin',
#  'Gregory Gideon',
#  'Gregory Herd',
#  'Gremlin (comics)',
#  'Grey Gargoyle',
#  'Griffin (Marvel Comics)',
#  'Grim Hunter',
#  'Grim Reaper (comics)',
#  'Grindhouse (comics)',
#  'Grizzly (comics)',
#  'Grog (Marvel Comics)',
#  'Groot',
#  'Growing Man',
#  'Guardian (Marvel Comics)',
#  'Guardsman (comics)',
#  'Guilt Hulk',
#  'Gunthar of Rigel',
#  'Gwenpool',
#  'Hack (comics)',
#  'Hala the Accuser',
#  'Hamilton Slade (mutant)',
#  'Hammer and Anvil (comics)',
#  'Hammerhead (comics)',
#  'Hank Pym',
#  'Hannibal King',
#  'Happy Sam Sawyer',
#  'Harbinger of Apocalypse',
#  'Hardball (comics)',
#  'Harold Meachum',
#  'Harry Leland',
#  'Harry Osborn',
#  'Hate-Monger',
#  'Hauptmann Deutschland',
#  'Havok (comics)',
#  'Hawkeye (Kate Bishop)',
#  'Hawkeye (comics)',
#  'Haywire (comics)',
#  'Headhunter (comics)',
#  'Headlok',
#  'Headsman (comics)',
#  'Hector (Marvel Comics)',
#  'Heinrich Zemo',
#  'Hela (comics)',
#  'Helix (Marvel Comics)',
#  'Helleyes',
#  'Hellfire (J. T. Slade)',
#  'Hellion (Marvel Comics)',
#  'Hellrazor',
#  'Hemingway (comics)',
#  'Henrietta Hunter',
#  'Henry Pym Jr.',
#  'Hepzibah (comics)',
#  'Hera (Marvel Comics)',
#  'Hercules (Marvel Comics)',
#  'Herr Kleiser',
#  'High Evolutionary',
#  'Hijacker (comics)',
#  'Hindsight (comics)',
#  'Hippo (comics)',
#  'Hippolyta (Marvel Comics)',
#  'Hiro Takachiho',
#  'Hiroim',
#  'Hit-Girl',
#  'Hit-Monkey',
#  'Hive (comics)',
#  'Hobgoblin (Imperial Guard)',
#  'Hobgoblin (comics)',
#  'Hogun',
#  'Holocaust (Marvel Comics)',
#  'Honey Lemon',
#  'Hood (comics)',
#  'Hoodwink (comics)',
#  'Hope Pym',
#  'Hope Summers (comics)',
#  'Hornet (comics)',
#  'Hrimhari',
#  'Hugh Jones (comics)',
#  'Hulk (comics)',
#  'Hulk 2099',
#  'Hulk Robot',
#  'Hulkbusters',
#  'Hulkling',
#  'Human Cannonball (Marvel Comics)',
#  'Human Fly (comics)',
#  'Human Top (Bruce Bravelle)',
#  'Human Top (David Mitchell)',
#  'Human Torch',
#  'Human Torch (android)',
#  'Humbug (comics)',
#  'Hummingbird (comics)',
#  'Humus Sapien',
#  'Huntsman (Marvel Comics)',
#  'Huntsman (comics)',
#  'Hurricane (comics)',
#  'Husk (comics)',
#  'Hussar (comics)',
#  'Hybrid (Jimmy Marks)',
#  'Hybrid (Scott Washington)',
#  'Hydro-Man',
#  'Hyperion (comics)',
#  'Hyperstorm',
#  'Hypno-Hustler',
#  'Hypnotia',
#  'ISAAC (comics)',
#  'Iceman (Marvel Comics)',
#  'Icemaster',
#  'Iguana (comics)',
#  'Ikaris',
#  'Ikthalon',
#  'Illusion (comics)',
#  'Immortus',
#  'Impala (Marvel Comics)',
#  'In-Betweener',
#  'Indra (comics)',
#  'Inertia (Marvel Comics)',
#  'Infectia',
#  'Inferno (Dante Pertuz)',
#  'Inferno (demon)',
#  'Infomorph (comics)',
#  'Ink (comics)',
#  'Institute of Evil',
#  'Invisible Woman',
#  'Ion (Marvel Comics)',
#  'Iron Cross (Marvel Comics)',
#  'Iron Fist (comics)',
#  'Iron Lad',
#  'Iron Maiden (comics)',
#  'Iron Man',
#  'Iron Man (Ultimate Marvel character)',
#  'Iron Man 2020',
#  'Iron Monger',
#  'Iron Patriot',
#  'Iron Spider',
#  'Ironclad (comics)',
#  'Isaiah Bradley',
#  'Isbisa',
#  'Isolationist (comics)',
#  'It! The Living Colossus',
#  'Izzy Cohen',
#  "J'son (comics)",
#  'J2 (comics)',
#  'Jack Flag',
#  'Jack Frost (Marvel Comics)',
#  "Jack O'Lantern (Marvel Comics)",
#  'Jack Power (Marvel Comics)',
#  'Jack Starsmore',
#  'Jack of Hearts',
#  'Jackal (Marvel Comics)',
#  'Jackhammer (comics)',
#  'Jackpot (comics)',
#  'Jacob Shaw (comics)',
#  'Jade Dragon',
#  'Jamie Braddock',
#  'Jamie Madrox',
#  'Jane Foster (comics)',
#  'Janice Lincoln',
#  'Jarella',
#  'Jason Macendale',
#  'Javelynn (comics)',
#  'Jazinda',
#  'Jean Grey',
#  'Jeffrey Mace',
#  'Jennifer Kale',
#  'Jerry Jaxon',
#  'Jessica Jones',
#  'Jester (Marvel Comics)',
#  'Jetstream (comics)',
#  'Jigsaw (Marvel Comics)',
#  'Jillian (comics)',
#  'Jimmy Woo',
#  'Jink Slater',
#  'Joanna Cargill',
#  'Jocasta (comics)',
#  'John Carik',
#  'John Jameson (comics)',
#  'John Ryker',
#  'John the Skrull',
#  'Johnny Dee',
#  'Jolen (comics)',
#  'Jolt (comics)',
#  'Jonas Harrow',
#  'Joseph (comics)',
#  'Josiah X',
#  'Joystick (comics)',
#  'Jubilee (comics)',
#  'Judas Traveller',
#  'Juggernaut (comics)',
#  'Julia Carpenter',
#  'Julie Power',
#  'June Covington',
#  'Junior Juniper',
#  'Junta (comics)',
#  'Junzo Muto',
#  'Justice (New Universe)',
#  'Justin Hammer',
#  'Juston Seyfert',
#  'Kaecilius',
#  'Kaine Parker',
#  'Kala (comics)',
#  'Kaluu',
#  'Kamikaze (comics)',
#  'Kang the Conqueror',
#  'Kangaroo (comics)',
#  'Karima Shapandar',
#  'Karl Malus',
#  'Karla Sofen',
#  'Karma (comics)',
#  'Karn (comics)',
#  'Karnak (comics)',
#  'Karnilla',
#  'Karolina Dean',
#  'Katie Power',
#  'Kearson DeWitt',
#  'Kenji Uedo',
#  'Kestrel (Marvel Comics)',
#  'Kevin Sydney',
#  'Kiber the Cruel',
#  'Kid Colt',
#  'Kid Kaiju',
#  'Killer Shrike',
#  'Killobyte (comics)',
#  'Killpower',
#  'Killraven',
#  'Kimura (comics)',
#  'King Arthur (Marvel Comics)',
#  'Kingmaker (comics)',
#  'Kingpin (character)',
#  'Kirigi',
#  'Kismet (Marvel Comics)',
#  'Kitty Pryde',
#  'Kiwi Black',
#  'Klara Prast',
#  'Klaw (Marvel Comics)',
#  'Kleinstocks',
#  'Kofi Whitemane',
#  'Komodo (comics)',
#  'Korath the Pursuer',
#  'Korg (comics)',
#  'Korvac',
#  'Korvus',
#  'Kraken (Marvel Comics)',
#  'Krang (Marvel Comics)',
#  'Kraven the Hunter',
#  'Kraven the Hunter (Alyosha Kravinoff)',
#  'Kraven the Hunter (Ana Kravinoff)',
#  'Kristoff Vernard',
#  'Kro (comics)',
#  'Krugarr',
#  'Kruun',
#  'Kulan Gath',
#  'Kurse',
#  'Kylun',
#  'La Lunatica',
#  'Lady Bullseye',
#  'Lady Deathstrike',
#  'Lady Gorgon',
#  'Lady Lotus',
#  'Lady Mastermind',
#  'Lady Octopus',
#  'Ladyhawk (comics)',
#  'Lamprey (comics)',
#  'Larry Trask (comics)',
#  'Lascivious (comics)',
#  'Lash (comics)',
#  'Laufey (comics)',
#  'Leader (comics)',
#  'Leap-Frog (comics)',
#  'Leech (comics)',
#  'Legion (Marvel Comics)',
#  'Lei Kung (comics)',
#  'Leila Davis',
#  'Lemuel Dorcas',
#  'Leo (comics)',
#  'Leonus',
#  'Leper Queen',
#  'Letha',
#  'Libra (Marvel Comics)',
#  'Lifeform (comics)',
#  'Lifeguard (comics)',
#  'Lifter (comics)',
#  'Lightmaster',
#  'Lila Cheney',
#  'Lilandra Neramani',
#  'Lilith (Marvel Comics)',
#  'Lin Sun',
#  'Lionheart (comics)',
#  'Living Brain',
#  'Living Diamond',
#  'Living Laser',
#  'Living Lightning',
#  'Living Monolith',
#  'Liz Allan',
#  'Lizard (comics)',
#  'Llan the Sorcerer',
#  'Lloyd Bloch',
#  'Llyra',
#  'Loa (comics)',
#  'Lobo Brothers',
#  'Lockheed (comics)',
#  'Lockjaw (comics)',
#  'Locus (comics)',
#  'Locust (comics)',
#  'Lodestone (comics)',
#  'Lois London',
#  'Loki (comics)',
#  'Longshot (Marvel Comics)',
#  'Looter (comics)',
#  'Lord Dark Wind',
#  'Lorelei (Asgardian)',
#  'Lorelei (Mutate)',
#  'Loss (comics)',
#  'Lotus Shinchuko',
#  ...]

# %%
import re, os

def get_partners(char, faction=None):
    """Return list of alliances for Marvel character."""
    if faction is None:
        for faction in ["superheroes", "supervillains", "ambiguous"]:
            #a list of characters in faction, with each of the file name without the .txt
            faction_chars = [c[:-4] for c in os.listdir("characters/%s" % faction)]
            if char in faction_chars:
                break
    
    # Load character markup
    with open("characters/%s/%s.txt" % (faction, char)) as fp:
        markup = fp.read()
        
    # Get partners field
    # Changed markup from "\| *partners[\w\W]+?\|.+=" to "\|*partners[\w\W]+?\\n\|"
    partners_field = re.findall(r"\| *partners[\w\W]+?\\n\|", markup)
    if partners_field == []:
        return []
 
    # Extract links from partners field
    return [t[2:-1] for t in re.findall(r"\[\[.+?[\]\|]", partners_field[0])]

# %%
def all_partners():
    all_partners = set()
    
    global all_heroes
    
    for h in all_heroes:
        try:
            partners = get_partners(h)
        except FileNotFoundError:
            print(f"{h} filenotfound")
            continue
        
        if 'Marvel Comics' in partners:
            print(h)
            continue
        else:
            for p in partners:
                all_partners.add(p)
    
    return all_partners
cx = all_partners()
print(sorted(cx))
# Out:
# Cate filenotfound
# Hazmat (Marvel Nem filenotfound
# Mark Haz filenotfound
# ['Abomination (comics)', 'Absorbing Man', 'Adam Warlock', 'Alicia Masters', 'Alpha the Ultimate Mutant', 'Amadeus Cho', 'Ancient One', 'Anya Corazon', 'Apocalypse (comics)', 'Arkon', 'Armin Zola', 'Attuma', 'Avengers (comics)', 'Awesome Android', 'Awesome Andy', 'Baron Helmut Zemo', 'Baron Mordo', 'Baron Strucker', 'Baron Zemo', 'Batroc the Leaper', 'Battlestar (comics)', 'Beast (comics)', 'Beetle (comics)', 'Belasco (comics)', 'Black Bolt', 'Black Cat (Marvel Comics)', 'Black Knight (Dane Whitman)', 'Black Panther (comics)', 'Black Panther (comics) ', 'Black Spectre#Black Spectre (organization)', 'Black Talon (comics)', 'Black Tom Cassidy', 'Black Widow (Natasha Romanova)', 'Blastaar', 'Blind Al', 'Blink (comics)', 'Bob, Agent of Hydra', 'Boomerang (comics)', 'Bucky (Marvel Comics)', 'Bucky Barnes', 'Byrrah', 'Cable (comics)', 'Captain America', 'Caretaker (comics)', 'Carnage (comics)', 'Carol Danvers', 'Carrion (comics)', 'Chameleon (comics)', 'Chimera (Marvel Comics)', 'Clea', 'Cloak and Dagger (comics)', 'Cobra (Marvel Comics)', 'Collector (comics)', 'Colleen Wing', 'Copycat (Marvel Comics)', 'Count Nefaria', 'Cowled Commander', 'Crimson Commando', 'Crimson Dynamo', 'Crossbones (comics)', 'Dakimh the Enchanter', 'Daredevil (Marvel Comics character)', 'Daredevil (Marvel Comics series)', 'Deadpool', 'Deathwatch (comics)', 'Demogoblin', 'Demolition Man (comics)', 'Devil Dinosaur', 'Diablo (Marvel Comics)', 'Dirtnap (comics)', 'Discus (comics)', 'Doctor Doom', 'Doctor Octopus', 'Doctor Strange', 'Domino (comics)', 'Doom 2099 (comics)', 'Doppelganger (comics)', 'Dorma (comics)', 'Dormammu', 'Dragon Man', 'Eddie Brock', 'Eel (comics)', 'Egghead (Marvel Comics)', 'Electro (Marvel Comics)', 'Elektra (comics)', 'Eli Bard', 'Elsa Bloodstone', 'Elsie-Dee', 'Emplate', 'Erik Josten', 'Erik Killmonger', 'Everett K. Ross', 'Executioner (comics)', 'Exodus (comics)', 'Falcon (comics)', 'Falcon (comics)#Other versions', 'Fantastic Four', 'Father Set', 'Fenris (comics)', 'Fenris Wolf (Marvel Comics)', 'Fifi the Duck', 'Fin (comics)', 'Fin Fang Foom', 'Fixer (comics)', 'Forge (comics)', 'Foursaken', 'Free Spirit (comics)', 'Frenchie (comics)', 'Fury (Marvel Comics)', 'Gambit (comics)', 'Gamora', 'Generation X (comics)', 'Ghaur', 'Ghost Rider', 'Gibbon (comics)', 'Gilded Lily (character)', 'Gladiator (Melvin Potter)', 'Glob (comics)', 'Gorgon (Inhuman)', 'Grand Director', 'Griffin (Marvel Comics)', 'Grim Reaper (comics)', 'Grizzly (comics)', 'Groot', 'Hammerhead (comics)', 'Hank Pym', 'Hawkeye (Kate Bishop)', 'Hawkeye (comics)', 'Headlok', 'Helmut Zemo', 'Henry Pym', 'Hercules (Marvel Comics)', 'Hiro Takachiho', 'Hood (comics)', 'Hope Summers (comics)', 'Howard the Duck', 'Hulk (comics)', 'Human Torch (android)', 'Hyperion (Supreme Power)', 'Iron Fist (comics)', 'Iron Man', 'J. Jonah Jameson', 'Jack Flag', 'Jack Monroe (comics)', 'Jackal (Marvel Comics)', 'Jessica Jones', 'Jester (Marvel Comics)#Jonathan Powers', 'Jigsaw (Marvel Comics)', 'John Blaze', 'Jonas Harrow', 'Juggernaut (comics)', 'Justin Hammer', 'Ka-Zar (comics)', 'Kala (comics)', 'Kamala Khan', 'Kang the Conqueror', 'Killpower', 'Kingpin (comics)', 'Klaw (Marvel Comics)', 'Korrek', 'Krang (Marvel Comics)', 'Kraven the Hunter', 'Kro (comics)', 'Leader (comics)', 'Lemuel Dorcas', 'Lilith (Marvel Comics)', 'Lilith (Marvel Comics)#Mother of all Demons', 'Llyra', 'Lois London', 'Loki (comics)', 'Lord Chaos (Marvel Comics)', 'Lucia von Bardas', 'Luke Cage', 'Mac Gargan', 'Mad Jim Jaspers', 'Mad Thinker', 'Madelyne Pryor', 'Madman (Marvel Comics)', 'Magik (Illyana Rasputin)', 'Magik (comics)', 'Magneto (comics)', 'Malekith the Accursed', 'Man-Ape', 'Man-Beast', 'Man-Bull', 'Man-Thing', 'Mandarin (comics)', 'Mandrill (comics)', 'Master Izo', 'Master Order', 'Mastermind (Martinique Jason)', 'Matador (Marvel Comics)', "Matsu\\'o Tsurayaba", 'Medusa (comics)', 'Mendel Stromm', 'Mentallo', 'Mephisto (comics)', 'Midgard Serpent (Marvel Comics)', "Midnight\\'s Fire", 'Mister Negative', 'Mister  ...

# %% [markdown]
# > **Ex: 6.2.2**: Create a `networkx.Graph` that represents each partnership between characters, as an edge. Print the number of nodes, edges and average degree of the resulting network.

# %%
import numpy as np
marvel = nx.Graph()

for hero in all_heroes:
    
    partners = get_partners(hero)
    for partner in partners:
        marvel.add_edge(hero,partner)
        
print ("Number of nodes: %d\nNumber of edges: %d\nAverage degree of network: %.4f" % (len(marvel.nodes), len(marvel.edges), np.mean(get_degrees(marvel))))
# Out:
# Number of nodes: 445
# Number of edges: 421
# Average degree of network: 1.8921

# %%
m_ax = plt.figure(figsize=(20,20))
nx.draw(marvel,node_size=20)

# %% [markdown]
# > **Ex: 6.2.3**: Plot the degree distribution of your character network. What type of random network does it resemble?

# %%
marvel_dist = get_degrees(marvel)

# %%
plt.hist(marvel_dist)
# Out:
# (array([358.,  33.,  22.,  23.,   4.,   3.,   0.,   1.,   0.,   1.]),
#  array([ 1. ,  2.3,  3.6,  4.9,  6.2,  7.5,  8.8, 10.1, 11.4, 12.7, 14. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# > **Ex: 6.2.4**: Create a bar chart (similar in style to the one in Ex. 3.2.1) with the 10 most high-degree characters in each class. Make sure that each subfigure has the same y-axis (control with `plt.ylim` or use `plt.subplots` with parameter `sharey=True`).

# %%
hero_partner = []
villain_partner = []
amb_partner = []

hero_graph = nx.Graph()
villain_graph = nx.Graph()
amb_graph = nx.Graph()
for fc, faction in enumerate(["superheroes", "ambiguous", "supervillains"]):
    faction_chars = [c[:-4] for c in os.listdir("characters/%s" % faction)]
    for char in faction_chars:
        try:
            partners = get_partners(char)
        except IOError:  # input error somehow.
            continue
        for p in partners:
            if fc == 0:
                hero_graph.add_edge(char, p)
                hero_partner.append((char,p))
            elif fc == 1:
                amb_graph.add_edge(char,p)
                amb_partner.append((char,p))
            elif fc == 2:
                villain_graph.add_edge(char,p)
                villain_partner.append((char,p))

# %%
from collections import OrderedDict
hero_top = OrderedDict(sorted(hero_graph.degree,key=lambda x: x[1],reverse=True)[:10])
villain_top = OrderedDict(sorted(villain_graph.degree,key=lambda x: x[1],reverse=True)[:10])
amb_top = OrderedDict(sorted(amb_graph.degree,key=lambda x: x[1],reverse=True)[:10])

# %%
fig = plt.figure(figsize=(13,18))

ax1 = plt.subplot(3,1,1)
plt.bar(hero_top.keys(), hero_top.values())
plt.xticks(rotation=60)
plt.title("Top 10 Hero by degrees")

plt.subplot(3,1,2,sharey=ax1)
plt.bar(villain_top.keys(), villain_top.values(),color='r')
plt.xticks(rotation=60)
plt.title("Top 10 Villains by degrees")

plt.subplot(3,1,3,sharey=ax1)
plt.bar(amb_top.keys(), amb_top.values(),color='m')
plt.xticks(rotation=60)
plt.title("Top 10 Amb by degrees")

plt.tight_layout()
plt.show()

# %% [markdown]
# > **Ex: 6.2.5**: Create a bar chart (similar in style to the one in Ex. 3.2.1) for each class with the characters that has the highest [betweenness centrality](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.centrality.betweenness_centrality.html) (BC). Again, make sure the y-axes are shared. When you comment on the result:
# * Explain briefly what the BC measures (and why it takes a short while to compute it). An intuitive explanation is also great!
# * Interpret, if you can, what the differences you see between the distribution of degree and BC means for the different classes.

# %%
hero_bc = nx.betweenness_centrality(hero_graph)
villain_bc = nx.betweenness_centrality(villain_graph)
amb_bc = nx.betweenness_centrality(amb_graph)

# BC is the sum of (total number shortest paths of one node to another that go through v) / (total number of shortest paths from one node to another). 
# It is the measure of how "inbetween" a node is in the graph. If a node has a high betweenness centrality (meaning that the centrality is close to 1) then 
# to find the shortest path, it is likely that it has to go through that node. It takes a while to compute it because with our large data set, it has to consider
# all the possible paths between two nodes.

# %%
def bc_chart(n=10):
    """Plots a bar chart of the top n highest betweenness centrality for each group. Default n = 10
    
    
    """
    
    global hero_bc, villain_bc, amb_bc
    
    # Sort them by value, turn into a dict, then splice from beginning to n
    sorted_amb_bc = dict(sorted(amb_bc.items(), key=lambda x: x[1], reverse=True)[:n])
    sorted_hero_bc = dict(sorted(hero_bc.items(), key=lambda x: x[1], reverse=True)[:n])
    sorted_villain_bc = dict(sorted(villain_bc.items(), key=lambda x: x[1], reverse=True)[:n])
    
    # Plots each with shared axes
    fig = plt.figure(figsize=(15,20))
    
    ax = plt.subplot(311)
    plt.title(f"Top {n} Heroes based on Betweenness Centrality")
    plt.bar(sorted_hero_bc.keys(), sorted_hero_bc.values(), color='b')
    plt.xticks(rotation=60)
    
    plt.subplot(312, sharey=ax)
    plt.title(f"Top {n} Villains based o Betweenness Centrality")
    plt.bar(sorted_villain_bc.keys(), sorted_villain_bc.values(), color='r')
    plt.xticks(rotation=60)
    
    plt.subplot(313, sharey=ax)
    plt.title(f"Top {n} ambiguous based on Betweenness Centrality")
    plt.bar(sorted_amb_bc.keys(), sorted_amb_bc.values(), color='m')
    plt.xticks(rotation=60)
    
    plt.tight_layout()
    plt.show()
bc_chart(10)

# %% [markdown]
# > **Ex: 6.2.6**: Create yet another similar bar chart where instead you measure the [local clustering coefficient](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.clustering.html#networkx.algorithms.cluster.clustering) (CC).
# * Explain briefly what the CC measures, and what it intuitively means that a node is highly clustered (CC=1) or not clustered at all (CC=0).
# * Interpret the difference between classes.

# %%
hero_cc = nx.clustering(hero_graph)
villain_cc = nx.clustering(villain_graph)
amb_cc = nx.clustering(amb_graph)
def cc_chart():
    """DOCSTRING"""
    

    
    sorted_hero_cc = dict(sorted(hero_cc.items(), key=lambda x: x[1], reverse=True))
    sorted_villain_cc = dict(sorted(villain_cc.items(), key=lambda x: x[1], reverse=True))
    sorted_amb_cc = dict(sorted(amb_cc.items(), key=lambda x: x[1], reverse=True))
    
    fig = plt.figure(figsize=(15,20))
    
    ax = plt.subplot(311)
    plt.title(f"Local clustering coefficient distribution of Heroes")
    plt.hist(sorted_hero_cc.values(), color='b')
    plt.xticks(rotation=60)
    
    plt.subplot(312, sharey=ax)
    plt.title(f"Local clustering coefficient distribution of Villains")
    plt.hist(sorted_villain_cc.values(), color='r')
    plt.xticks(rotation=60)
    
    plt.subplot(313, sharey=ax)
    plt.title(f"Local clustering coefficient distribution of Ambiguous")
    plt.hist(sorted_amb_cc.values(), color='m')
    plt.xticks(rotation=60)
    
    plt.tight_layout()
    plt.show()
    
cc_chart()

# %% [markdown]
# > **Extra: Ex: 6.2**: There seems to be some correlation between BC, degree and clustering, but it definitely doesn't look perfect. Try to make a scatter plot of characters' degree vs. their BC. If time permits, pimp your plot by:
# * Prettifying your plot by:
#     * Setting appropriate axis limits and labels
#     * Fontsizes, figure title, etc.
#     * Adding a slight amount of *jitter* to the degree
# * Coloring nodes by class (hero: blue, villain: red, ambiguous: yellow)
# * Scaling node sizes by the CC (add an offset so no nodes have size 0).
#
# > Highlight your findings:
# * Which characters have an unusually high centrality compared to their degree and vice versa? How can you explain this?
# * Does this inspire you to think about new things that can be investigated?

# %%
hero_degrees = dict(hero_graph.degree(hero_graph))
villain_degrees = dict(villain_graph.degree(villain_graph))
amb_degrees = dict(amb_graph.degree(amb_graph))

# %%
fig = plt.figure(figsize=(20,20))

plt.title("Degree vs Betweenness centrality")
plt.scatter(hero_degrees.values(), hero_bc.values(), s=[(3+c)**6 for c in hero_cc.values()], label='Heroes', edgecolor='w')
plt.scatter(villain_degrees.values(), villain_bc.values(), s=[(3+c)**6 for c in villain_cc.values()], label='Villains',edgecolor='w')
plt.scatter(amb_degrees.values(), amb_bc.values(), s=[(3+c)**6 for c in amb_cc.values()], label='Amb', edgecolor='w')

plt.ylim(bottom=-0.005)

plt.xlabel("Degrees")
plt.ylabel("Betweenness Centrality")
plt.legend(loc='best', markerscale = .4, prop={'size': 15})
plt.show()

# %% [markdown]
# > **Ex: 6.2.7**: We want to plot the network so we can visually get a feeling for how characters are connected. However, the network is too big to plot without some kind of pre-processing. Therefore, we remove all links between nodes that are not on the top 10 list of high-degree characters within their class.
# * Color the nodes by class. Try if you can to use blue for heroes, red for villains and yellow for ambiguous.
# * Scale the size of nodes by the square root of their degree.
# * Adjust the layout of the figure so it doesn't look too messy (e.g. edge line width, node line width, type of force-layout [I can recommend *neato*, but you have to install graphviz with conda to use it])
# * Do you see anything interesting? Get any new ideas for things that can be investigated?
#
# > *Hint: I actually made [a tool](https://ulfaslak.com/works/network_styling_with_d3/index.html) for making pretty visualizations of networks. I'd be curious to see the Marvel network visualized in my tool.*

# %%
def graph_top(n=10):
    
    global hero_graph, villain_graph, amb_graph
    

    
    # These are the ones whose nodes should not have connections
    sorted_h = dict(sorted(dict(hero_graph.degree).items(), key=lambda x: x[1], reverse=True)[n:])
    sorted_v = dict(sorted(dict(villain_graph.degree).items(), key=lambda x: x[1], reverse=True)[n:])
    sorted_a = dict(sorted(dict(amb_graph.degree).items(), key=lambda x: x[1], reverse=True)[n:])
    
    color_map = []
    all_g = nx.compose(hero_graph, nx.compose(villain_graph,amb_graph))
    
    for node in all_g:
        if node in hero_graph.node:
            color_map.append('blue')
        elif node in villain_graph.node:
            color_map.append('red')
        elif node in amb_graph.node:
            color_map.append('magenta')
    
    plt.figure(figsize=(20,20))
    
    tops = list(sorted_h.keys()) + list(sorted_v.keys()) + list(sorted_a.keys())
    
    to_remove = [(t1, t2) for t1 in tops if t1 in tops for t2 in tops if t2 in tops]
    
    all_g.remove_edges_from(to_remove)
    
    nx.draw(all_g, node_size=20, node_color=color_map)
    
graph_top()
